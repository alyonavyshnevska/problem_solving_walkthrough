# %% [markdown]
# #### Problem Solving using Python  -  [`problemsolving.io`](https://problemsolving.io/)

# %% [markdown]
# # Mini-Project - Develop a "Problem Solving Walkthrough" (20 pts = 100%)
#
# In this mini-project, you are going to write a "problem solving walkthrough". You will choose a programming problem, and solve it by documenting the process following our model. The deliverable is this Jupyter Notebook.
#
# ## Walkthrough
# The problem solving **walkthrough** is a written **guided description** of the journey from a problem to a solution. Detailed reasoning is performed and written for each one of the phases. For example, in the first phase, besides stating the problem in your own words you should include at least a few input-output pairs. As another example, a well-performed design phase contains several drafts showing gradual improvements. It should also justify your choice of datastructures.
#
# **Incremental development** is the preferred way to apply the model. Get something working and keep it working. If you decide not to follow this methodology, please make sure you explain why.
#
#
# ### Structure
# Solving a problem may be messy sometimes and non-linear. Keep in mind that your goal is to guide the reader through solving the problem in a logical and clear manner, so you shouldn't record all the twists and turns you had. The walkthrough is a "better version of the truth". However if you encounter an interesting or teachable bug, you are encouraged to document how you solved the bug (hint: reproduce, diagnose, fix, reflect). In fact, you can get extra credit for that (read more in evaluation section)!
#
#
# <div class="alert alert-info">
# <h3>Tip for Writing a Walkthrough</h3>
# Consider a fellow student in the class as your audience. Your goal is to lead her/him through the process, and the text should reflect it. We find that writing using the "first person plural" ("we") is the most convenient way for that purpose.
# </div>
#
#
# ## Our Expectations
# For inspiration, you can look at the notebook we used in the lecture of week 11 about the [Viterbi Algorithm](https://problemsolving.io/materials-up-ws18-19/lectures/11-viterbi-anlp3.zip). We expect the same formatting and level of detail even though the problems you'll be solving for this project are a lot simpler than Viterbi.
#
#
# ## Evaluation
# First and foremost, we will evaluate your programming problem solving process and your reasoning on each phase. We won't evaluate your English per se, but you should make your text clear for another student. You can assume that your audience is proficient in Python.
# Extra credit: If you perform the debug phase on a bug you've encountered, you can get up to 4 extra points.
#
#
# ## Permitted Materials
# You know the drill by now. No external websites, except for course materials and the websites in the resources dropdown in the top bar at https://problemsolving.io. Definitely neither Stack Overflow nor Googling.
#
#
# ## Programming Problems
# The list below contains some problems from *Advent of Code*. Most of them are the same level of difficulty and a couple are more complex as indicated by the peppers.
# Please pick two or three of them and rank them in terms of preference, then send them to us on **Piazza** and **get our approval** before you start working on it.
# There are more problems than registered students, so we would like to ensure that everyone works on a different problem.
# First come, first served.
#
#
# 1. [AoC 2016 - Day 10](https://adventofcode.com/2016/day/10)
# 2. [AoC 2016 - Day 12](https://adventofcode.com/2016/day/12)
# 3. [AoC 2016 - Day 18](https://adventofcode.com/2016/day/18)
# 4. [AoC 2016 - Day 23](https://adventofcode.com/2016/day/23)
# 6. [AoC 2017 - Day 3](https://adventofcode.com/2017/day/3)
# 5. [AoC 2017 - Day 6](https://adventofcode.com/2017/day/6)
# 6. [AoC 2017 - Day 8](https://adventofcode.com/2017/day/8)
# 6. [AoC 2017 - Day 7](https://adventofcode.com/2017/day/7)   🌶️
# 7. [AoC 2017 - Day 10](https://adventofcode.com/2017/day/10) 🌶️🌶️
# 8. [AoC 2017 - Day 11](https://adventofcode.com/2017/day/11)
# 9. [AoC 2017 - Day 12](https://adventofcode.com/2017/day/12)
# 10. [AoC 2017 - Day 13](https://adventofcode.com/2017/day/13)
# 11. [AoC 2017 - Day 19](https://adventofcode.com/2017/day/19)
# 12. [AoC 2017 - Day 20](https://adventofcode.com/2017/day/20)
# 13. [AoC 2018 - Day 7](https://adventofcode.com/2018/day/7)
#
# **Important:** Save the *input* you get from Advent of Code website as a file **input.txt** in the root directory of the homework.

# %%
# Check that the file `input.txt` exists in the root directory of the homework

import os

assert os.path.exists('input.txt')

# %% [markdown]
# <hr style="height: 10px; background-color:black;">
# <hr style="height: 10px; background-color:black;">

# %% [markdown]
# # Programming Problem Solving Walkthrough
#
# # The Sum of Its Parts
#
# ## Written by: Olena Vyshnevska
#
# ## The Problem
#
# You find yourself standing on a snow-covered coastline; apparently, you landed a little off course. The region is too hilly to see the North Pole from here, but you do spot some Elves that seem to be trying to unpack something that washed ashore. It's quite cold out, so you decide to risk creating a paradox by asking them for directions.
#
# "Oh, are you the search party?" Somehow, you can understand whatever Elves from the year 1018 speak; you assume it's Ancient Nordic Elvish. Could the device on your wrist also be a translator? "Those clothes don't look very warm; take this." They hand you a heavy coat.
#
# "We do need to find our way back to the North Pole, but we have higher priorities at the moment. You see, believe it or not, this box contains something that will solve all of Santa's transportation problems - at least, that's what it looks like from the pictures in the instructions." It doesn't seem like they can read whatever language it's in, but you can: "Sleigh kit. Some assembly required."
#
# "'Sleigh'? What a wonderful name! You must help us assemble this 'sleigh' at once!" They start excitedly pulling more parts out of the box.
#
# The instructions specify a series of steps and requirements about which steps must be finished before others can begin (your puzzle input). Each step is designated by a single letter. For example, suppose you have the following instructions:
#
#     Step C must be finished before step A can begin.
#     Step C must be finished before step F can begin.
#     Step A must be finished before step B can begin.
#     Step A must be finished before step D can begin.
#     Step B must be finished before step E can begin.
#     Step D must be finished before step E can begin.
#     Step F must be finished before step E can begin.
#
# Visually, these requirements look like this:
#
#
#       -->A--->B--
#      /    \      \
#     C      -->D----->E
#      \           /
#       ---->F-----
#
# Your first goal is to determine the order in which the steps should be completed. If more than one step is ready, choose the step which is first alphabetically. In this example, the steps would be completed as follows:
#
#     Only C is available, and so it is done first.
#     Next, both A and F are available. A is first alphabetically, so it is done next.
#     Then, even though F was available earlier, steps B and D are now also available, and B is the first alphabetically of the three.
#     After that, only D and F are available. E is not available because only some of its prerequisites are complete. Therefore, D is completed next.
#     F is the only choice, so it is done next.
#     Finally, E is completed.
#
# So, in this example, the correct order is CABDFE.
#
# In what order should the steps in your instructions be completed?

# %% [markdown]
# ## And Now, Let's Solve It!
#
# In this notebook, we wiil solve a programming problem in a in a methodical and thoughtful manner, using the *[Programming Problem Solving Model](https://handbook.problemsolving.io)*, and follow the *Incremental Development* methodology.
#
# <div class="alert alert-info">
#   <h4>Programming Problem Solving Model</h4>
#   <ol>
#     <li>Reinterpret the Problem</li>
#     <li>Design a Solution</li>
#     <li>Code</li>
#     <li>Test</li>
#     <li>Debug</li>
#     <li>Evaluate & Reflect</li>
#   </ol>
# </div>
#
# <div class="alert alert-info">
#   <h4>Incremental Development</h4>
#   <ul>
#     <li>Rapid cycles of Problem + Design + Code + Test + Debug</li>
#     <li>Start small and keep it working</li>
#   </ul>
# </div>

# %% [markdown]
# <a id="problem-phase-top"></a>
# <div class="alert alert-info">
# <h3>Reinterpret the Problem (3 pts)</h3>
# </div>

# %% [markdown]
# A set of instructions is available.
# Each instruction has a form:
# Step X must be finished before step Y can begin.
#
# Goal: find the correct order of steps.
# Desired output form: a string with letters representing the correct order.
#
# If more than one step can be taken at one point, take the step which is alphabetically first.
#
# -----
#
# Examples of input-output pairs:
#
# ### Example 1
#
# Input:
# Step A must be finished before step C can begin.
# Step A must be finished before step D can begin.
# Step C must be finished before step B can begin.
# Step D must be finished before step B can begin.
#
#
#       -->C
#      /    \
#     A        -->B
#      \      /
#       ---->D
#
#
# Output:
# "ACDB"
#
# ### Example 2
#
# Input:
# Step C must be finished before step D can begin.
# Step D must be finished before step A can begin.
# Step D must be finished before step E can begin.
#
#
#            -->A
#           /    \
#     C -->D  ----->E
#
#
#  Output: "CDAE"

# %% [markdown]
# <div class="alert alert-info">
# <h3>Design a Solution (4 pts)</h3>
# </div>

# %% [markdown]
# ## Design 1
#
# **What do we need to create the output string of correct order of steps?**
#
# _Idea_:
# An alphabetically ordered list of available steps.
# Per iteration:
# First step from the available steps list added to the string of correct order. Removed from the list of available steps.
# Steps that depend on it are added to the list of available steps.
#
#
# **What do we need to build such ordered list?**
# - Look-up possibility: given a finished step, what steps can begin?
# - A starting point
#
# **Look-up**
# A dictionary provides an easy access to a list of newly available steps after a step is finished.
# Key = finished step
# Value = newly available steps
#
#
# ### Issue
# Consider the following scenario:
#
#       -->B
#      /    \
#     A        -->D
#      \      /
#       ---->C
#
# This case will contain a statement:
# Step B must be finished before step D can begin.
#
# Once step B is finished, step D will be added to the list of available steps.
# But, step D is not available yet, because we haven't taken step C.
#
# Verdict: Improvement of design needed.
# Given a step, what are all steps that have to be **already completed** to take it.

# %% [markdown]
# ## Design 2
#
# An alphabetically ordered list of available steps.
#
# Per iteration:
# In _dependencies_ dictionary check which steps have empty sets of steps that have to be finished beforehand.
# Add these steps to the _available steps_ list.
# Remove them from _dependencies_ dictionary.
#
#
# Add the first step X from the sorted _available steps_ list to the _order_ string.
# Remove X from the _available steps_ list.
# Remove X from from all sets that have it as a dependency in the _dependencies_ dictionary.
#
# **Starting point**
# Find steps that depend on steps that have no dependency lists. The latter are the starting points.
# If more than one, decide alphabetically.
#
# **When to stop?**
# When the _dependencies_ dictionary becomes empty, meaning that all of the steps have been taken.

# %% [markdown]
# ### Choice and Reasoning behind Data Structures:
#
# Dictionary for dependencies: easy and quick look up of dependencies for a step.
#
# Set of dependencies within _dependencies_ dictionary: again, quick and easy look-up. No need for order, no repetitions.
#
# Available steps: initially a set. Turned into a list each time _sorted()_ function is applied to it.
#
# Steps in order: a string to which steps will be appended to its end.

# %% [markdown]
# ### Breaking into Subproblems
# So, we have **subproblems**:
# - Create a look-up possibility for: list what dependencies does a step have
#     - Figure out the starting point: list steps that have one dependency. Pick one, which dependency does not appear as a key in the dictionary, meaning that it has no dependencies.
# - Iteratively add the steps to _available steps_ set and take them in alphabetical order.
#
# ### Design for the First Sub-problem
#
# - create a dictionary with steps as keys and a set of steps that has to be finished beforehand as value
# - read in input file line by line
# - if the line not empty: add the step as a key, append a step that needs to be finished beforehand as value
# - create a set of steps in the _dependencies_ dictionary that have only one dependency
#
# ### Design for the Second Subproblem
# - With each iteration:
#     - Add the _steps_ to _available steps_ list. Remove it from _dependencies_ dict.
#     - Add first item of the sorted _available steps_ to the string _order_. Remove it from the _available steps_ list

# %% [markdown]
# <div class="alert alert-info">
# <h3>Code (4 pts)</h3>
# </div>

# %%
from collections import defaultdict

# %% [markdown]
# ## Code for First Subproblem: Creating Look-up Dictionary

# %%
def create_dependencies_dictionary(filename):
    '''Creates a dictionary with steps as keys and a list of required previous steps as values
    
    :param filename: filename with step descriptions. One step description per line.
    :return: a dictionary of dependencies'''
    dependencies = defaultdict(list)

    with open(filename, 'r') as instructions_file:
        for line in instructions_file:
            if len(line) > 1:
                step_to_begin = line[-13]
                dependency_step = line[5]

                dependencies[step_to_begin].append(dependency_step)
                
    return dependencies

# %%
def find_possible_starts(available_steps, dependencies):
    '''Finds possible starts: stes that do not require any other previous steps

    :param available_steps: empty list where possible starts will be stored
    :return: list of possible starts '''

    non_dependencies_list = set()
    # each step that has one dependency should be considered
    for step, dep_steps in sorted(dependencies.items()):
        for dep_step in dep_steps:
            if dep_step not in dependencies:
                non_dependencies_list.add(dep_step)
                if len(dep_steps) == 1:
                    available_steps.add(dep_steps[0])
                    
    return sorted(available_steps)

# %% [markdown]
# ## Code for Second Subproblem: Find Correct Order

# %%
def take_step(available_steps, steps_in_order, dependencies):
    ''''''
    
    step_to_take = sorted(available_steps)[0]
    steps_in_order += step_to_take
    available_steps.remove(step_to_take)

    steps_to_delete_from_dict = []
    
    for step, dep_steps in dependencies.items():
        if step_to_take in dep_steps:
            dep_steps.remove(step_to_take)
        if dep_steps == []:
            available_steps.add(step)
            steps_to_delete_from_dict.append(step)
            
    #remove taken steps from dependencies dictionary        
    for step_to_delete in steps_to_delete_from_dict:
        del dependencies[step_to_delete]
        
    return step_to_take, steps_in_order

# %%
def main():
    dependencies = create_dependencies_dictionary('input.txt')
    
    #display dictionary with dependencies
    print("Dictionary of Dependencies: ")
    for key, value in sorted(dependencies.items()):
        print(key, ": ", value)
        
    available_steps = set()
    possible_starts = find_possible_starts(available_steps, dependencies)
    print("\nPossible starts:", possible_starts)
    
    steps_in_order = ""
    
    while dependencies.keys():
        
        step_taken = take_step(available_steps, steps_in_order, dependencies)
        print("Step taken: ", step_taken[0])
        print("Steps in Order", step_taken[1])
        print("Available Steps: ", available_steps)
        print("Dictionary of Dependencies: ")
        for key, value in sorted(dependencies.items()):
            print(key, ": ", value)

# %% [markdown]
# <div class="alert alert-info">
# <h3>Test (3 pts)</h3>
# </div>

# %%
main()
# Out:
# Dictionary of Dependencies:
# A :  ['W', 'L', 'Y', 'J', 'U', 'K']
# C :  ['J', 'H', 'Y', 'W', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'N', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'G', 'I']
# H :  ['X', 'N', 'I']
# I :  ['F', 'X', 'T']
# J :  ['U', 'Z', 'Y', 'M']
# K :  ['B']
# L :  ['K', 'G', 'M', 'P']
# M :  ['K', 'U', 'R']
# N :  ['F']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V', 'K', 'N']
# P :  ['H', 'I', 'G']
# Q :  ['H', 'U', 'W', 'T']
# R :  ['B']
# S :  ['N', 'C', 'O', 'X', 'Z', 'Y', 'Q', 'L', 'D']
# T :  ['B']
# U :  ['T', 'I', 'F']
# V :  ['H', 'W', 'T', 'P', 'L']
# W :  ['T', 'R']
# X :  ['R']
# Y :  ['X', 'I', 'V', 'Q', 'P', 'O', 'R', 'N', 'B', 'W']
# Z :  ['R', 'T', 'G', 'B']
#
# Possible starts: ['B', 'F']
# Step taken:  B
# Steps in Order B
# Available Steps:  {'R', 'K', 'T', 'F'}
# Dictionary of Dependencies:
# A :  ['W', 'L', 'Y', 'J', 'U', 'K']
# C :  ['J', 'H', 'Y', 'W', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'N', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'G', 'I']
# H :  ['X', 'N', 'I']
# I :  ['F', 'X', 'T']
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['K', 'G', 'M', 'P']
# M :  ['K', 'U', 'R']
# N :  ['F']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V', 'K', 'N']
# P :  ['H', 'I', 'G']
# Q :  ['H', 'U', 'W', 'T']
# S :  ['N', 'C', 'O', 'X', 'Z', 'Y', 'Q', 'L', 'D']
# U :  ['T', 'I', 'F']
# V :  ['H', 'W', 'T', 'P', 'L']
# W :  ['T', 'R']
# X :  ['R']
# Y :  ['X', 'I', 'V', 'Q', 'P', 'O', 'R', 'N', 'W']
# Z :  ['R', 'T', 'G']
# Step taken:  F
# Steps in Order F
# Available Steps:  {'R', 'K', 'T', 'N'}
# Dictionary of Dependencies:
# A :  ['W', 'L', 'Y', 'J', 'U', 'K']
# C :  ['J', 'H', 'Y', 'W', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'N', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'G', 'I']
# H :  ['X', 'N', 'I']
# I :  ['X', 'T']
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['K', 'G', 'M', 'P']
# M :  ['K', 'U', 'R']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V', 'K', 'N']
# P :  ['H', 'I', 'G']
# Q :  ['H', 'U', 'W', 'T']
# S :  ['N', 'C', 'O', 'X', 'Z', 'Y', 'Q', 'L', 'D']
# U :  ['T', 'I']
# V :  ['H', 'W', 'T', 'P', 'L']
# W :  ['T', 'R']
# X :  ['R']
# Y :  ['X', 'I', 'V', 'Q', 'P', 'O', 'R', 'N', 'W']
# Z :  ['R', 'T', 'G']
# Step taken:  K
# Steps in Order K
# Available Steps:  {'R', 'T', 'N'}
# Dictionary of Dependencies:
# A :  ['W', 'L', 'Y', 'J', 'U']
# C :  ['J', 'H', 'Y', 'W', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'N', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'G', 'I']
# H :  ['X', 'N', 'I']
# I :  ['X', 'T']
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['G', 'M', 'P']
# M :  ['U', 'R']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V', 'N']
# P :  ['H', 'I', 'G']
# Q :  ['H', 'U', 'W', 'T']
# S :  ['N', 'C', 'O', 'X', 'Z', 'Y', 'Q', 'L', 'D']
# U :  ['T', 'I']
# V :  ['H', 'W', 'T', 'P', 'L']
# W :  ['T', 'R']
# X :  ['R']
# Y :  ['X', 'I', 'V', 'Q', 'P', 'O', 'R', 'N', 'W']
# Z :  ['R', 'T', 'G']
# Step taken:  N
# Steps in Order N
# Available Steps:  {'R', 'T'}
# Dictionary of Dependencies:
# A :  ['W', 'L', 'Y', 'J', 'U']
# C :  ['J', 'H', 'Y', 'W', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'G', 'I']
# H :  ['X', 'I']
# I :  ['X', 'T']
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['G', 'M', 'P']
# M :  ['U', 'R']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V']
# P :  ['H', 'I', 'G']
# Q :  ['H', 'U', 'W', 'T']
# S :  ['C', 'O', 'X', 'Z', 'Y', 'Q', 'L', 'D']
# U :  ['T', 'I']
# V :  ['H', 'W', 'T', 'P', 'L']
# W :  ['T', 'R']
# X :  ['R']
# Y :  ['X', 'I', 'V', 'Q', 'P', 'O', 'R', 'W']
# Z :  ['R', 'T', 'G']
# Step taken:  R
# Steps in Order R
# Available Steps:  {'X', 'T'}
# Dictionary of Dependencies:
# A :  ['W', 'L', 'Y', 'J', 'U']
# C :  ['J', 'H', 'Y', 'W', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'G', 'I']
# H :  ['X', 'I']
# I :  ['X', 'T']
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['G', 'M', 'P']
# M :  ['U']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V']
# P :  ['H', 'I', 'G']
# Q :  ['H', 'U', 'W', 'T']
# S :  ['C', 'O', 'X', 'Z', 'Y', 'Q', 'L', 'D']
# U :  ['T', 'I']
# V :  ['H', 'W', 'T', 'P', 'L']
# W :  ['T']
# Y :  ['X', 'I', 'V', 'Q', 'P', 'O', 'W']
# Z :  ['T', 'G']
# Step taken:  T
# Steps in Order T
# Available Steps:  {'X', 'W'}
# Dictionary of Dependencies:
# A :  ['W', 'L', 'Y', 'J', 'U']
# C :  ['J', 'H', 'Y', 'W', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'G', 'I']
# H :  ['X', 'I']
# I :  ['X']
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['G', 'M', 'P']
# M :  ['U']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V']
# P :  ['H', 'I', 'G']
# Q :  ['H', 'U', 'W']
# S :  ['C', 'O', 'X', 'Z', 'Y', 'Q', 'L', 'D']
# U :  ['I']
# V :  ['H', 'W', 'P', 'L']
# Y :  ['X', 'I', 'V', 'Q', 'P', 'O', 'W']
# Z :  ['G']
# Step taken:  W
# Steps in Order W
# Available Steps:  {'X'}
# Dictionary of Dependencies:
# A :  ['L', 'Y', 'J', 'U']
# C :  ['J', 'H', 'Y', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'G', 'I']
# H :  ['X', 'I']
# I :  ['X']
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['G', 'M', 'P']
# M :  ['U']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V']
# P :  ['H', 'I', 'G']
# Q :  ['H', 'U']
# S :  ['C', 'O', 'X', 'Z', 'Y', 'Q', 'L', 'D']
# U :  ['I']
# V :  ['H', 'P', 'L']
# Y :  ['X', 'I', 'V', 'Q', 'P', 'O']
# Z :  ['G']
# Step taken:  X
# Steps in Order X
# Available Steps:  {'I'}
# Dictionary of Dependencies:
# A :  ['L', 'Y', 'J', 'U']
# C :  ['J', 'H', 'Y', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'G', 'I']
# H :  ['I']
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['G', 'M', 'P']
# M :  ['U']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V']
# P :  ['H', 'I', 'G']
# Q :  ['H', 'U']
# S :  ['C', 'O', 'Z', 'Y', 'Q', 'L', 'D']
# U :  ['I']
# V :  ['H', 'P', 'L']
# Y :  ['I', 'V', 'Q', 'P', 'O']
# Z :  ['G']
# Step taken:  I
# Steps in Order I
# Available Steps:  {'H', 'U'}
# Dictionary of Dependencies:
# A :  ['L', 'Y', 'J', 'U']
# C :  ['J', 'H', 'Y', 'A', 'L', 'P']
# D :  ['O', 'J', 'P', 'H', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'G']
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['G', 'M', 'P']
# M :  ['U']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V']
# P :  ['H', 'G']
# Q :  ['H', 'U']
# S :  ['C', 'O', 'Z', 'Y', 'Q', 'L', 'D']
# V :  ['H', 'P', 'L']
# Y :  ['V', 'Q', 'P', 'O']
# Z :  ['G']
# Step taken:  H
# Steps in Order H
# Available Steps:  {'U'}
# Dictionary of Dependencies:
# A :  ['L', 'Y', 'J', 'U']
# C :  ['J', 'Y', 'A', 'L', 'P']
# D :  ['O', 'J', 'P', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'G']
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['G', 'M', 'P']
# M :  ['U']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V']
# P :  ['G']
# Q :  ['U']
# S :  ['C', 'O', 'Z', 'Y', 'Q', 'L', 'D']
# V :  ['P', 'L']
# Y :  ['V', 'Q', 'P', 'O']
# Z :  ['G']
# Step taken:  U
# Steps in Order U
# Available Steps:  {'M', 'Q'}
# Dictionary of Dependencies:
# A :  ['L', 'Y', 'J']
# C :  ['J', 'Y', 'A', 'L', 'P']
# D :  ['O', 'J', 'P', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'G']
# J :  ['Z', 'Y', 'M']
# L :  ['G', 'M', 'P']
# O :  ['Z', 'L', 'P', 'Q', 'V']
# P :  ['G']
# S :  ['C', 'O', 'Z', 'Y', 'Q', 'L', 'D']
# V :  ['P', 'L']
# Y :  ['V', 'Q', 'P', 'O']
# Z :  ['G']
# Step taken:  M
# Steps in Order M
# Available Steps:  {'Q'}
# Dictionary of Dependencies:
# A :  ['L', 'Y', 'J']
# C :  ['J', 'Y', 'A', 'L', 'P']
# D :  ['O', 'J', 'P', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'G']
# J :  ['Z', 'Y']
# L :  ['G', 'P']
# O :  ['Z', 'L', 'P', 'Q', 'V']
# P :  ['G']
# S :  ['C', 'O', 'Z', 'Y', 'Q', 'L', 'D']
# V :  ['P', 'L']
# Y :  ['V', 'Q', 'P', 'O']
# Z :  ['G']
# Step taken:  Q
# Steps in Order Q
# Available Steps:  set()
# Dictionary of Dependencies:
# A :  ['L', 'Y', 'J']
# C :  ['J', 'Y', 'A', 'L', 'P']
# D :  ['O', 'J', 'P', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'G']
# J :  ['Z', 'Y']
# L :  ['G', 'P']
# O :  ['Z', 'L', 'P', 'V']
# P :  ['G']
# S :  ['C', 'O', 'Z', 'Y', 'L', 'D']
# V :  ['P', 'L']
# Y :  ['V', 'P', 'O']
# Z :  ['G']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-263240bbee7e> in <module>
# ----> 1 main()
#
# <ipython-input-24-bbb524a0110f> in main()
#      15     while dependencies.keys():
#      16
# ---> 17         step_taken = take_step(available_steps, steps_in_order, dependencies)
#      18         print("Step taken: ", step_taken[0])
#      19         print("Steps in Order", step_taken[1])
#
# <ipython-input-23-373e8048a252> in take_step(available_steps, steps_in_order, dependencies)
#       2     ''''''
#       3
# ----> 4     step_to_take = sorted(available_steps)[0]
#       5     steps_in_order += step_to_take
#       6     available_steps.remove(step_to_take)
#
# IndexError: list index out of range

# %% [markdown]
# <div class="alert alert-info">
# <h3>Debug (EXTRA CREDIT: 4 pts)</h3>
# <div class="alert alert-warning">
# <h3>Debug</h3>
#
# 1. Reproduce
# 2. Diagnose
# 3. Fix
# 4. Reflect
#
# </div></div>

# %% [markdown]
# ##### 1. Reproduce
#
#     IndexError: list index out of range
#
# After some iterations, list of available steps is empty, however, there are instructions in the _delendencies_ dict left.
#
#
# ##### 2. Diagnose
# The following code causes the problem
#
#             if dep_step not in dependencies:
#                 non_dependencies_list.add(dep_step)
#                 if len(dep_steps) == 1:
#                     available_steps.add(dep_steps[0])
#
# Only steps that have one dependency are added to the available steps.
# However, in sets of dependencies of steps there can be dependencies that are free to be added to the available steps set (in other words, that themselves do not have dependencies).
#
# ##### 3. Fix
#
# Add every step, that does not appear in the _dependencies_ dict as a key to the set of available steps.
#
# The following lines have to be deleted:
#
#                 if len(dep_steps) == 1:
#                     available_steps.add(dep_steps[0])
#
# The non dependencies list has to be returned as available steps set:
#
#             if dep_step not in dependencies:
#                 non_dependencies_list.add(dep_step)
#
# Now it makes sense to skip the creation of non dependencies list and add steps, which have no dependencies straight to the available steps set.
#
#
# ##### 4. Reflect
# It seemes logical at first that we want to start with step that has only one dependency, which can be taken right away. But, I did not consider the case in which we might find a dependency for a step, that require many previous steps, but that one dependency has nothing that needs to be done before.
#
# The good thing was to stumble upon this mistake, understand why this has happend and now to rethink how I perceive this bit of the task.

# %%
def find_possible_starts(available_steps, dependencies):
    '''Finds possible starts: sets that do not require any other previous steps. Adds them to
    available steps set

    :param available_steps: empty list where possible starts will be stored
    :param dependencies: dict with keys: steps, values=set of their dependencies
    :return: list of possible starts '''


    for step, dep_steps in sorted(dependencies.items()):
        for dep_step in dep_steps:
            if dep_step not in dependencies:
                available_steps.add(dep_step)

    print("Avaliable: ", available_steps)   
    return available_steps

# %%
def take_step(available_steps, steps_in_order, dependencies):
    '''
    Takes the first element from the sorted list of available steps to ensure alphabetical
    taking of available steps. Adds it to string of steps in order.
    Removes the step taken from dependencies.
    
    :param available_steps: set of available steps
    :param steps_in_order: string with current steps in order
    :param dependencies: dict with keys: steps, values=set of their dependencies'''
    
    step_to_take = sorted(available_steps)[0]
    steps_in_order += step_to_take
    available_steps.remove(step_to_take)
    if step_to_take in dependencies:
        del dependencies[step_to_take]
        
    return step_to_take, steps_in_order

# %%
def add_available_steps(step_taken, available_steps, dependencies):
    ''' Adds steps that became available after a step has been taken to the set
    of available steps.
    Removes a taken steps from sets of depedendencies in dependencies dict'''
    
    for step, dep_steps in dependencies.items():
        if step_taken in dep_steps:
            dep_steps.remove(step_taken)
        if dep_steps == []:
            available_steps.add(step)
        
    return available_steps

# %%
def main():
    dependencies = create_dependencies_dictionary('input.txt')
    
    #display dictionary with dependencies
    print("Dictionary of Dependencies: ")
    for key, value in sorted(dependencies.items()):
        print(key, ": ", value)
        
    available_steps = set()
    find_possible_starts(available_steps, dependencies)
    
    steps_in_order = ""
    
    while dependencies.keys():
        
        step_taken, steps_in_order = take_step(available_steps, steps_in_order, dependencies)
        print("Step taken: ", step_taken[0])
        print("Steps in Order", steps_in_order)
        print("Available Steps: ", available_steps)
        print("Dictionary of Dependencies: ")
        for key, value in sorted(dependencies.items()):
            print(key, ": ", value)

        add_available_steps(step_taken, available_steps, dependencies)
        print("Available Steps: ", available_steps)
        print("Dictionary of Dependencies: ")
        for key, value in sorted(dependencies.items()):
            print(key, ": ", value)
            
    
    return steps_in_order

# %% [markdown]
# <div class="alert alert-success">
# <h3>Execute the Program and Solve the Problem!</h3>
# </div>

# %%
main()
# Out:
# Dictionary of Dependencies:
# A :  ['W', 'L', 'Y', 'J', 'U', 'K']
# C :  ['J', 'H', 'Y', 'W', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'N', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'G', 'I']
# H :  ['X', 'N', 'I']
# I :  ['F', 'X', 'T']
# J :  ['U', 'Z', 'Y', 'M']
# K :  ['B']
# L :  ['K', 'G', 'M', 'P']
# M :  ['K', 'U', 'R']
# N :  ['F']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V', 'K', 'N']
# P :  ['H', 'I', 'G']
# Q :  ['H', 'U', 'W', 'T']
# R :  ['B']
# S :  ['N', 'C', 'O', 'X', 'Z', 'Y', 'Q', 'L', 'D']
# T :  ['B']
# U :  ['T', 'I', 'F']
# V :  ['H', 'W', 'T', 'P', 'L']
# W :  ['T', 'R']
# X :  ['R']
# Y :  ['X', 'I', 'V', 'Q', 'P', 'O', 'R', 'N', 'B', 'W']
# Z :  ['R', 'T', 'G', 'B']
# Avaliable:  {'F', 'G', 'B'}
# Step taken:  B
# Steps in Order B
# Available Steps:  {'F', 'G'}
# Dictionary of Dependencies:
# A :  ['W', 'L', 'Y', 'J', 'U', 'K']
# C :  ['J', 'H', 'Y', 'W', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'N', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'G', 'I']
# H :  ['X', 'N', 'I']
# I :  ['F', 'X', 'T']
# J :  ['U', 'Z', 'Y', 'M']
# K :  ['B']
# L :  ['K', 'G', 'M', 'P']
# M :  ['K', 'U', 'R']
# N :  ['F']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V', 'K', 'N']
# P :  ['H', 'I', 'G']
# Q :  ['H', 'U', 'W', 'T']
# R :  ['B']
# S :  ['N', 'C', 'O', 'X', 'Z', 'Y', 'Q', 'L', 'D']
# T :  ['B']
# U :  ['T', 'I', 'F']
# V :  ['H', 'W', 'T', 'P', 'L']
# W :  ['T', 'R']
# X :  ['R']
# Y :  ['X', 'I', 'V', 'Q', 'P', 'O', 'R', 'N', 'B', 'W']
# Z :  ['R', 'T', 'G', 'B']
# Available Steps:  {'R', 'K', 'G', 'T', 'F'}
# Dictionary of Dependencies:
# A :  ['W', 'L', 'Y', 'J', 'U', 'K']
# C :  ['J', 'H', 'Y', 'W', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'N', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'G', 'I']
# H :  ['X', 'N', 'I']
# I :  ['F', 'X', 'T']
# J :  ['U', 'Z', 'Y', 'M']
# K :  []
# L :  ['K', 'G', 'M', 'P']
# M :  ['K', 'U', 'R']
# N :  ['F']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V', 'K', 'N']
# P :  ['H', 'I', 'G']
# Q :  ['H', 'U', 'W', 'T']
# R :  []
# S :  ['N', 'C', 'O', 'X', 'Z', 'Y', 'Q', 'L', 'D']
# T :  []
# U :  ['T', 'I', 'F']
# V :  ['H', 'W', 'T', 'P', 'L']
# W :  ['T', 'R']
# X :  ['R']
# Y :  ['X', 'I', 'V', 'Q', 'P', 'O', 'R', 'N', 'W']
# Z :  ['R', 'T', 'G']
# Step taken:  F
# Steps in Order BF
# Available Steps:  {'R', 'K', 'G', 'T'}
# Dictionary of Dependencies:
# A :  ['W', 'L', 'Y', 'J', 'U', 'K']
# C :  ['J', 'H', 'Y', 'W', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'N', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'G', 'I']
# H :  ['X', 'N', 'I']
# I :  ['F', 'X', 'T']
# J :  ['U', 'Z', 'Y', 'M']
# K :  []
# L :  ['K', 'G', 'M', 'P']
# M :  ['K', 'U', 'R']
# N :  ['F']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V', 'K', 'N']
# P :  ['H', 'I', 'G']
# Q :  ['H', 'U', 'W', 'T']
# R :  []
# S :  ['N', 'C', 'O', 'X', 'Z', 'Y', 'Q', 'L', 'D']
# T :  []
# U :  ['T', 'I', 'F']
# V :  ['H', 'W', 'T', 'P', 'L']
# W :  ['T', 'R']
# X :  ['R']
# Y :  ['X', 'I', 'V', 'Q', 'P', 'O', 'R', 'N', 'W']
# Z :  ['R', 'T', 'G']
# Available Steps:  {'R', 'K', 'G', 'T', 'N'}
# Dictionary of Dependencies:
# A :  ['W', 'L', 'Y', 'J', 'U', 'K']
# C :  ['J', 'H', 'Y', 'W', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'N', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'G', 'I']
# H :  ['X', 'N', 'I']
# I :  ['X', 'T']
# J :  ['U', 'Z', 'Y', 'M']
# K :  []
# L :  ['K', 'G', 'M', 'P']
# M :  ['K', 'U', 'R']
# N :  []
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V', 'K', 'N']
# P :  ['H', 'I', 'G']
# Q :  ['H', 'U', 'W', 'T']
# R :  []
# S :  ['N', 'C', 'O', 'X', 'Z', 'Y', 'Q', 'L', 'D']
# T :  []
# U :  ['T', 'I']
# V :  ['H', 'W', 'T', 'P', 'L']
# W :  ['T', 'R']
# X :  ['R']
# Y :  ['X', 'I', 'V', 'Q', 'P', 'O', 'R', 'N', 'W']
# Z :  ['R', 'T', 'G']
# Step taken:  G
# Steps in Order BFG
# Available Steps:  {'R', 'K', 'T', 'N'}
# Dictionary of Dependencies:
# A :  ['W', 'L', 'Y', 'J', 'U', 'K']
# C :  ['J', 'H', 'Y', 'W', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'N', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'G', 'I']
# H :  ['X', 'N', 'I']
# I :  ['X', 'T']
# J :  ['U', 'Z', 'Y', 'M']
# K :  []
# L :  ['K', 'G', 'M', 'P']
# M :  ['K', 'U', 'R']
# N :  []
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V', 'K', 'N']
# P :  ['H', 'I', 'G']
# Q :  ['H', 'U', 'W', 'T']
# R :  []
# S :  ['N', 'C', 'O', 'X', 'Z', 'Y', 'Q', 'L', 'D']
# T :  []
# U :  ['T', 'I']
# V :  ['H', 'W', 'T', 'P', 'L']
# W :  ['T', 'R']
# X :  ['R']
# Y :  ['X', 'I', 'V', 'Q', 'P', 'O', 'R', 'N', 'W']
# Z :  ['R', 'T', 'G']
# Available Steps:  {'R', 'K', 'T', 'N'}
# Dictionary of Dependencies:
# A :  ['W', 'L', 'Y', 'J', 'U', 'K']
# C :  ['J', 'H', 'Y', 'W', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'N', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'I']
# H :  ['X', 'N', 'I']
# I :  ['X', 'T']
# J :  ['U', 'Z', 'Y', 'M']
# K :  []
# L :  ['K', 'M', 'P']
# M :  ['K', 'U', 'R']
# N :  []
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V', 'K', 'N']
# P :  ['H', 'I']
# Q :  ['H', 'U', 'W', 'T']
# R :  []
# S :  ['N', 'C', 'O', 'X', 'Z', 'Y', 'Q', 'L', 'D']
# T :  []
# U :  ['T', 'I']
# V :  ['H', 'W', 'T', 'P', 'L']
# W :  ['T', 'R']
# X :  ['R']
# Y :  ['X', 'I', 'V', 'Q', 'P', 'O', 'R', 'N', 'W']
# Z :  ['R', 'T']
# Step taken:  K
# Steps in Order BFGK
# Available Steps:  {'R', 'T', 'N'}
# Dictionary of Dependencies:
# A :  ['W', 'L', 'Y', 'J', 'U', 'K']
# C :  ['J', 'H', 'Y', 'W', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'N', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'I']
# H :  ['X', 'N', 'I']
# I :  ['X', 'T']
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['K', 'M', 'P']
# M :  ['K', 'U', 'R']
# N :  []
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V', 'K', 'N']
# P :  ['H', 'I']
# Q :  ['H', 'U', 'W', 'T']
# R :  []
# S :  ['N', 'C', 'O', 'X', 'Z', 'Y', 'Q', 'L', 'D']
# T :  []
# U :  ['T', 'I']
# V :  ['H', 'W', 'T', 'P', 'L']
# W :  ['T', 'R']
# X :  ['R']
# Y :  ['X', 'I', 'V', 'Q', 'P', 'O', 'R', 'N', 'W']
# Z :  ['R', 'T']
# Available Steps:  {'R', 'T', 'N'}
# Dictionary of Dependencies:
# A :  ['W', 'L', 'Y', 'J', 'U']
# C :  ['J', 'H', 'Y', 'W', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'N', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'I']
# H :  ['X', 'N', 'I']
# I :  ['X', 'T']
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['M', 'P']
# M :  ['U', 'R']
# N :  []
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V', 'N']
# P :  ['H', 'I']
# Q :  ['H', 'U', 'W', 'T']
# R :  []
# S :  ['N', 'C', 'O', 'X', 'Z', 'Y', 'Q', 'L', 'D']
# T :  []
# U :  ['T', 'I']
# V :  ['H', 'W', 'T', 'P', 'L']
# W :  ['T', 'R']
# X :  ['R']
# Y :  ['X', 'I', 'V', 'Q', 'P', 'O', 'R', 'N', 'W']
# Z :  ['R', 'T']
# Step taken:  N
# Steps in Order BFGKN
# Available Steps:  {'R', 'T'}
# Dictionary of Dependencies:
# A :  ['W', 'L', 'Y', 'J', 'U']
# C :  ['J', 'H', 'Y', 'W', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'N', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'I']
# H :  ['X', 'N', 'I']
# I :  ['X', 'T']
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['M', 'P']
# M :  ['U', 'R']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V', 'N']
# P :  ['H', 'I']
# Q :  ['H', 'U', 'W', 'T']
# R :  []
# S :  ['N', 'C', 'O', 'X', 'Z', 'Y', 'Q', 'L', 'D']
# T :  []
# U :  ['T', 'I']
# V :  ['H', 'W', 'T', 'P', 'L']
# W :  ['T', 'R']
# X :  ['R']
# Y :  ['X', 'I', 'V', 'Q', 'P', 'O', 'R', 'N', 'W']
# Z :  ['R', 'T']
# Available Steps:  {'R', 'T'}
# Dictionary of Dependencies:
# A :  ['W', 'L', 'Y', 'J', 'U']
# C :  ['J', 'H', 'Y', 'W', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'I']
# H :  ['X', 'I']
# I :  ['X', 'T']
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['M', 'P']
# M :  ['U', 'R']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V']
# P :  ['H', 'I']
# Q :  ['H', 'U', 'W', 'T']
# R :  []
# S :  ['C', 'O', 'X', 'Z', 'Y', 'Q', 'L', 'D']
# T :  []
# U :  ['T', 'I']
# V :  ['H', 'W', 'T', 'P', 'L']
# W :  ['T', 'R']
# X :  ['R']
# Y :  ['X', 'I', 'V', 'Q', 'P', 'O', 'R', 'W']
# Z :  ['R', 'T']
# Step taken:  R
# Steps in Order BFGKNR
# Available Steps:  {'T'}
# Dictionary of Dependencies:
# A :  ['W', 'L', 'Y', 'J', 'U']
# C :  ['J', 'H', 'Y', 'W', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'I']
# H :  ['X', 'I']
# I :  ['X', 'T']
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['M', 'P']
# M :  ['U', 'R']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V']
# P :  ['H', 'I']
# Q :  ['H', 'U', 'W', 'T']
# S :  ['C', 'O', 'X', 'Z', 'Y', 'Q', 'L', 'D']
# T :  []
# U :  ['T', 'I']
# V :  ['H', 'W', 'T', 'P', 'L']
# W :  ['T', 'R']
# X :  ['R']
# Y :  ['X', 'I', 'V', 'Q', 'P', 'O', 'R', 'W']
# Z :  ['R', 'T']
# Available Steps:  {'X', 'T'}
# Dictionary of Dependencies:
# A :  ['W', 'L', 'Y', 'J', 'U']
# C :  ['J', 'H', 'Y', 'W', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'I']
# H :  ['X', 'I']
# I :  ['X', 'T']
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['M', 'P']
# M :  ['U']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V']
# P :  ['H', 'I']
# Q :  ['H', 'U', 'W', 'T']
# S :  ['C', 'O', 'X', 'Z', 'Y', 'Q', 'L', 'D']
# T :  []
# U :  ['T', 'I']
# V :  ['H', 'W', 'T', 'P', 'L']
# W :  ['T']
# X :  []
# Y :  ['X', 'I', 'V', 'Q', 'P', 'O', 'W']
# Z :  ['T']
# Step taken:  T
# Steps in Order BFGKNRT
# Available Steps:  {'X'}
# Dictionary of Dependencies:
# A :  ['W', 'L', 'Y', 'J', 'U']
# C :  ['J', 'H', 'Y', 'W', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'I']
# H :  ['X', 'I']
# I :  ['X', 'T']
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['M', 'P']
# M :  ['U']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V']
# P :  ['H', 'I']
# Q :  ['H', 'U', 'W', 'T']
# S :  ['C', 'O', 'X', 'Z', 'Y', 'Q', 'L', 'D']
# U :  ['T', 'I']
# V :  ['H', 'W', 'T', 'P', 'L']
# W :  ['T']
# X :  []
# Y :  ['X', 'I', 'V', 'Q', 'P', 'O', 'W']
# Z :  ['T']
# Available Steps:  {'Z', 'X', 'W'}
# Dictionary of Dependencies:
# A :  ['W', 'L', 'Y', 'J', 'U']
# C :  ['J', 'H', 'Y', 'W', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'I']
# H :  ['X', 'I']
# I :  ['X']
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['M', 'P']
# M :  ['U']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V']
# P :  ['H', 'I']
# Q :  ['H', 'U', 'W']
# S :  ['C', 'O', 'X', 'Z', 'Y', 'Q', 'L', 'D']
# U :  ['I']
# V :  ['H', 'W', 'P', 'L']
# W :  []
# X :  []
# Y :  ['X', 'I', 'V', 'Q', 'P', 'O', 'W']
# Z :  []
# Step taken:  W
# Steps in Order BFGKNRTW
# Available Steps:  {'Z', 'X'}
# Dictionary of Dependencies:
# A :  ['W', 'L', 'Y', 'J', 'U']
# C :  ['J', 'H', 'Y', 'W', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'I']
# H :  ['X', 'I']
# I :  ['X']
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['M', 'P']
# M :  ['U']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V']
# P :  ['H', 'I']
# Q :  ['H', 'U', 'W']
# S :  ['C', 'O', 'X', 'Z', 'Y', 'Q', 'L', 'D']
# U :  ['I']
# V :  ['H', 'W', 'P', 'L']
# X :  []
# Y :  ['X', 'I', 'V', 'Q', 'P', 'O', 'W']
# Z :  []
# Available Steps:  {'Z', 'X'}
# Dictionary of Dependencies:
# A :  ['L', 'Y', 'J', 'U']
# C :  ['J', 'H', 'Y', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'I']
# H :  ['X', 'I']
# I :  ['X']
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['M', 'P']
# M :  ['U']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V']
# P :  ['H', 'I']
# Q :  ['H', 'U']
# S :  ['C', 'O', 'X', 'Z', 'Y', 'Q', 'L', 'D']
# U :  ['I']
# V :  ['H', 'P', 'L']
# X :  []
# Y :  ['X', 'I', 'V', 'Q', 'P', 'O']
# Z :  []
# Step taken:  X
# Steps in Order BFGKNRTWX
# Available Steps:  {'Z'}
# Dictionary of Dependencies:
# A :  ['L', 'Y', 'J', 'U']
# C :  ['J', 'H', 'Y', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'I']
# H :  ['X', 'I']
# I :  ['X']
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['M', 'P']
# M :  ['U']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V']
# P :  ['H', 'I']
# Q :  ['H', 'U']
# S :  ['C', 'O', 'X', 'Z', 'Y', 'Q', 'L', 'D']
# U :  ['I']
# V :  ['H', 'P', 'L']
# Y :  ['X', 'I', 'V', 'Q', 'P', 'O']
# Z :  []
# Available Steps:  {'Z', 'I'}
# Dictionary of Dependencies:
# A :  ['L', 'Y', 'J', 'U']
# C :  ['J', 'H', 'Y', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'I']
# H :  ['I']
# I :  []
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['M', 'P']
# M :  ['U']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V']
# P :  ['H', 'I']
# Q :  ['H', 'U']
# S :  ['C', 'O', 'Z', 'Y', 'Q', 'L', 'D']
# U :  ['I']
# V :  ['H', 'P', 'L']
# Y :  ['I', 'V', 'Q', 'P', 'O']
# Z :  []
# Step taken:  I
# Steps in Order BFGKNRTWXI
# Available Steps:  {'Z'}
# Dictionary of Dependencies:
# A :  ['L', 'Y', 'J', 'U']
# C :  ['J', 'H', 'Y', 'A', 'L', 'I', 'P']
# D :  ['O', 'J', 'P', 'H', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q', 'I']
# H :  ['I']
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['M', 'P']
# M :  ['U']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V']
# P :  ['H', 'I']
# Q :  ['H', 'U']
# S :  ['C', 'O', 'Z', 'Y', 'Q', 'L', 'D']
# U :  ['I']
# V :  ['H', 'P', 'L']
# Y :  ['I', 'V', 'Q', 'P', 'O']
# Z :  []
# Available Steps:  {'H', 'Z', 'U'}
# Dictionary of Dependencies:
# A :  ['L', 'Y', 'J', 'U']
# C :  ['J', 'H', 'Y', 'A', 'L', 'P']
# D :  ['O', 'J', 'P', 'H', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q']
# H :  []
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['M', 'P']
# M :  ['U']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V']
# P :  ['H']
# Q :  ['H', 'U']
# S :  ['C', 'O', 'Z', 'Y', 'Q', 'L', 'D']
# U :  []
# V :  ['H', 'P', 'L']
# Y :  ['V', 'Q', 'P', 'O']
# Z :  []
# Step taken:  H
# Steps in Order BFGKNRTWXIH
# Available Steps:  {'Z', 'U'}
# Dictionary of Dependencies:
# A :  ['L', 'Y', 'J', 'U']
# C :  ['J', 'H', 'Y', 'A', 'L', 'P']
# D :  ['O', 'J', 'P', 'H', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q']
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['M', 'P']
# M :  ['U']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V']
# P :  ['H']
# Q :  ['H', 'U']
# S :  ['C', 'O', 'Z', 'Y', 'Q', 'L', 'D']
# U :  []
# V :  ['H', 'P', 'L']
# Y :  ['V', 'Q', 'P', 'O']
# Z :  []
# Available Steps:  {'Z', 'U', 'P'}
# Dictionary of Dependencies:
# A :  ['L', 'Y', 'J', 'U']
# C :  ['J', 'Y', 'A', 'L', 'P']
# D :  ['O', 'J', 'P', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q']
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['M', 'P']
# M :  ['U']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V']
# P :  []
# Q :  ['U']
# S :  ['C', 'O', 'Z', 'Y', 'Q', 'L', 'D']
# U :  []
# V :  ['P', 'L']
# Y :  ['V', 'Q', 'P', 'O']
# Z :  []
# Step taken:  P
# Steps in Order BFGKNRTWXIHP
# Available Steps:  {'Z', 'U'}
# Dictionary of Dependencies:
# A :  ['L', 'Y', 'J', 'U']
# C :  ['J', 'Y', 'A', 'L', 'P']
# D :  ['O', 'J', 'P', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q']
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['M', 'P']
# M :  ['U']
# O :  ['U', 'Z', 'L', 'P', 'Q', 'V']
# Q :  ['U']
# S :  ['C', 'O', 'Z', 'Y', 'Q', 'L', 'D']
# U :  []
# V :  ['P', 'L']
# Y :  ['V', 'Q', 'P', 'O']
# Z :  []
# Available Steps:  {'Z', 'U'}
# Dictionary of Dependencies:
# A :  ['L', 'Y', 'J', 'U']
# C :  ['J', 'Y', 'A', 'L']
# D :  ['O', 'J', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q']
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['M']
# M :  ['U']
# O :  ['U', 'Z', 'L', 'Q', 'V']
# Q :  ['U']
# S :  ['C', 'O', 'Z', 'Y', 'Q', 'L', 'D']
# U :  []
# V :  ['L']
# Y :  ['V', 'Q', 'O']
# Z :  []
# Step taken:  U
# Steps in Order BFGKNRTWXIHPU
# Available Steps:  {'Z'}
# Dictionary of Dependencies:
# A :  ['L', 'Y', 'J', 'U']
# C :  ['J', 'Y', 'A', 'L']
# D :  ['O', 'J', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q']
# J :  ['U', 'Z', 'Y', 'M']
# L :  ['M']
# M :  ['U']
# O :  ['U', 'Z', 'L', 'Q', 'V']
# Q :  ['U']
# S :  ['C', 'O', 'Z', 'Y', 'Q', 'L', 'D']
# V :  ['L']
# Y :  ['V', 'Q', 'O']
# Z :  []
# Available Steps:  {'Z', 'M', 'Q'}
# Dictionary of Dependencies:
# A :  ['L', 'Y', 'J']
# C :  ['J', 'Y', 'A', 'L']
# D :  ['O', 'J', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q']
# J :  ['Z', 'Y', 'M']
# L :  ['M']
# M :  []
# O :  ['Z', 'L', 'Q', 'V']
# Q :  []
# S :  ['C', 'O', 'Z', 'Y', 'Q', 'L', 'D']
# V :  ['L']
# Y :  ['V', 'Q', 'O']
# Z :  []
# Step taken:  M
# Steps in Order BFGKNRTWXIHPUM
# Available Steps:  {'Z', 'Q'}
# Dictionary of Dependencies:
# A :  ['L', 'Y', 'J']
# C :  ['J', 'Y', 'A', 'L']
# D :  ['O', 'J', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q']
# J :  ['Z', 'Y', 'M']
# L :  ['M']
# O :  ['Z', 'L', 'Q', 'V']
# Q :  []
# S :  ['C', 'O', 'Z', 'Y', 'Q', 'L', 'D']
# V :  ['L']
# Y :  ['V', 'Q', 'O']
# Z :  []
# Available Steps:  {'Z', 'Q', 'L'}
# Dictionary of Dependencies:
# A :  ['L', 'Y', 'J']
# C :  ['J', 'Y', 'A', 'L']
# D :  ['O', 'J', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q']
# J :  ['Z', 'Y']
# L :  []
# O :  ['Z', 'L', 'Q', 'V']
# Q :  []
# S :  ['C', 'O', 'Z', 'Y', 'Q', 'L', 'D']
# V :  ['L']
# Y :  ['V', 'Q', 'O']
# Z :  []
# Step taken:  L
# Steps in Order BFGKNRTWXIHPUML
# Available Steps:  {'Z', 'Q'}
# Dictionary of Dependencies:
# A :  ['L', 'Y', 'J']
# C :  ['J', 'Y', 'A', 'L']
# D :  ['O', 'J', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q']
# J :  ['Z', 'Y']
# O :  ['Z', 'L', 'Q', 'V']
# Q :  []
# S :  ['C', 'O', 'Z', 'Y', 'Q', 'L', 'D']
# V :  ['L']
# Y :  ['V', 'Q', 'O']
# Z :  []
# Available Steps:  {'V', 'Z', 'Q'}
# Dictionary of Dependencies:
# A :  ['Y', 'J']
# C :  ['J', 'Y', 'A']
# D :  ['O', 'J', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q']
# J :  ['Z', 'Y']
# O :  ['Z', 'Q', 'V']
# Q :  []
# S :  ['C', 'O', 'Z', 'Y', 'Q', 'D']
# V :  []
# Y :  ['V', 'Q', 'O']
# Z :  []
# Step taken:  Q
# Steps in Order BFGKNRTWXIHPUMLQ
# Available Steps:  {'V', 'Z'}
# Dictionary of Dependencies:
# A :  ['Y', 'J']
# C :  ['J', 'Y', 'A']
# D :  ['O', 'J', 'Q', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O', 'Q']
# J :  ['Z', 'Y']
# O :  ['Z', 'Q', 'V']
# S :  ['C', 'O', 'Z', 'Y', 'Q', 'D']
# V :  []
# Y :  ['V', 'Q', 'O']
# Z :  []
# Available Steps:  {'V', 'Z'}
# Dictionary of Dependencies:
# A :  ['Y', 'J']
# C :  ['J', 'Y', 'A']
# D :  ['O', 'J', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O']
# J :  ['Z', 'Y']
# O :  ['Z', 'V']
# S :  ['C', 'O', 'Z', 'Y', 'D']
# V :  []
# Y :  ['V', 'O']
# Z :  []
# Step taken:  V
# Steps in Order BFGKNRTWXIHPUMLQV
# Available Steps:  {'Z'}
# Dictionary of Dependencies:
# A :  ['Y', 'J']
# C :  ['J', 'Y', 'A']
# D :  ['O', 'J', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O']
# J :  ['Z', 'Y']
# O :  ['Z', 'V']
# S :  ['C', 'O', 'Z', 'Y', 'D']
# Y :  ['V', 'O']
# Z :  []
# Available Steps:  {'Z'}
# Dictionary of Dependencies:
# A :  ['Y', 'J']
# C :  ['J', 'Y', 'A']
# D :  ['O', 'J', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O']
# J :  ['Z', 'Y']
# O :  ['Z']
# S :  ['C', 'O', 'Z', 'Y', 'D']
# Y :  ['O']
# Z :  []
# Step taken:  Z
# Steps in Order BFGKNRTWXIHPUMLQVZ
# Available Steps:  set()
# Dictionary of Dependencies:
# A :  ['Y', 'J']
# C :  ['J', 'Y', 'A']
# D :  ['O', 'J', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O']
# J :  ['Z', 'Y']
# O :  ['Z']
# S :  ['C', 'O', 'Z', 'Y', 'D']
# Y :  ['O']
# Available Steps:  {'O'}
# Dictionary of Dependencies:
# A :  ['Y', 'J']
# C :  ['J', 'Y', 'A']
# D :  ['O', 'J', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O']
# J :  ['Y']
# O :  []
# S :  ['C', 'O', 'Y', 'D']
# Y :  ['O']
# Step taken:  O
# Steps in Order BFGKNRTWXIHPUMLQVZO
# Available Steps:  set()
# Dictionary of Dependencies:
# A :  ['Y', 'J']
# C :  ['J', 'Y', 'A']
# D :  ['O', 'J', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S', 'O']
# J :  ['Y']
# S :  ['C', 'O', 'Y', 'D']
# Y :  ['O']
# Available Steps:  {'Y'}
# Dictionary of Dependencies:
# A :  ['Y', 'J']
# C :  ['J', 'Y', 'A']
# D :  ['J', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S']
# J :  ['Y']
# S :  ['C', 'Y', 'D']
# Y :  []
# Step taken:  Y
# Steps in Order BFGKNRTWXIHPUMLQVZOY
# Available Steps:  set()
# Dictionary of Dependencies:
# A :  ['Y', 'J']
# C :  ['J', 'Y', 'A']
# D :  ['J', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S']
# J :  ['Y']
# S :  ['C', 'Y', 'D']
# Available Steps:  {'J'}
# Dictionary of Dependencies:
# A :  ['J']
# C :  ['J', 'A']
# D :  ['J', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S']
# J :  []
# S :  ['C', 'D']
# Step taken:  J
# Steps in Order BFGKNRTWXIHPUMLQVZOYJ
# Available Steps:  set()
# Dictionary of Dependencies:
# A :  ['J']
# C :  ['J', 'A']
# D :  ['J', 'C', 'A']
# E :  ['J', 'A', 'C', 'D', 'S']
# S :  ['C', 'D']
# Available Steps:  {'A'}
# Dictionary of Dependencies:
# A :  []
# C :  ['A']
# D :  ['C', 'A']
# E :  ['A', 'C', 'D', 'S']
# S :  ['C', 'D']
# Step taken:  A
# Steps in Order BFGKNRTWXIHPUMLQVZOYJA
# Available Steps:  set()
# Dictionary of Dependencies:
# C :  ['A']
# D :  ['C', 'A']
# E :  ['A', 'C', 'D', 'S']
# S :  ['C', 'D']
# Available Steps:  {'C'}
# Dictionary of Dependencies:
# C :  []
# D :  ['C']
# E :  ['C', 'D', 'S']
# S :  ['C', 'D']
# Step taken:  C
# Steps in Order BFGKNRTWXIHPUMLQVZOYJAC
# Available Steps:  set()
# Dictionary of Dependencies:
# D :  ['C']
# E :  ['C', 'D', 'S']
# S :  ['C', 'D']
# Available Steps:  {'D'}
# Dictionary of Dependencies:
# D :  []
# E :  ['D', 'S']
# S :  ['D']
# Step taken:  D
# Steps in Order BFGKNRTWXIHPUMLQVZOYJACD
# Available Steps:  set()
# Dictionary of Dependencies:
# E :  ['D', 'S']
# S :  ['D']
# Available Steps:  {'S'}
# Dictionary of Dependencies:
# E :  ['S']
# S :  []
# Step taken:  S
# Steps in Order BFGKNRTWXIHPUMLQVZOYJACDS
# Available Steps:  set()
# Dictionary of Dependencies:
# E :  ['S']
# Available Steps:  {'E'}
# Dictionary of Dependencies:
# E :  []
# Step taken:  E
# Steps in Order BFGKNRTWXIHPUMLQVZOYJACDSE
# Available Steps:  set()
# Dictionary of Dependencies:
# Available Steps:  set()
# Dictionary of Dependencies:
# 'BFGKNRTWXIHPUMLQVZOYJACDSE'

# %% [markdown]
# ### Redesign: Efficiency
# The code works, but there is a way to make it more efficient:
#     create a second look-up dictionary with key = step, values = steps that depend on that key.
# Then, instead of looping over entire dependencies each time a step has been taken to find which
# steps required it as their dependencies,
# we just loop over steps that depend on the step taken.
#
# For example,
#
#         if steps A,C, and D depend on B:
#             the entry in the
#             {'B' : ['A', 'C', 'D']}
#
# Once B is accomplished: we remove it from the sets of depencencies of three steps A,C, and D.
#
# _dependencies_ dictionary: key=step, value=its dependencies
# _steps that follow_ dictionary: key=step, value=steps that follow the key

# %%
def create_dependencies_dictionaries(filename):
    '''Creates a dictionary with steps as keys and a list of required previous steps as values
    
    :param filename: filename with step descriptions. One step description per line.
    :return: a dictionary of dependencies'''
    
    dependencies = defaultdict(set)
    steps_that_follow = defaultdict(set)

    with open(filename, 'r') as instructions_file:
        for line in instructions_file:
            if len(line) > 1:
                step_to_begin = line[-13]
                dependency_step = line[5]

                dependencies[step_to_begin].add(dependency_step)
                steps_that_follow[dependency_step].add(step_to_begin)
                
    return dependencies, steps_that_follow

# %%
def find_possible_starts2(dependencies):
    '''Finds possible starts: stes that do not require any other previous steps.
    And remove 

    :param available_steps: empty list where possible starts will be stored
    :return: list of possible starts '''

    available_steps = set()
    
    for step, dep_steps in dependencies.items():
        for dep_step in dep_steps:
            if dep_step not in dependencies:
                available_steps.add(dep_step)

    return available_steps

# %%
def take_step2(available_steps, steps_in_order, dependencies):
    step_to_take = sorted(available_steps)[0]
    steps_in_order += step_to_take
    available_steps.remove(step_to_take)
    if step_to_take in dependencies:
        del dependencies[step_to_take]
        
    return step_to_take, steps_in_order

# %%
def add_available_steps2(step_taken, available_steps, dependencies, steps_that_follow):
    ''' Adds steps that became available after a step has been taken to the set
    of available steps.
    Removes a taken steps from sets of depedendencies in dependencies dict'''
    
    
    for step in steps_that_follow[step_taken]:
        dependencies[step].remove(step_taken)
        if dependencies[step] == set():
            available_steps.add(step)
        
    return available_steps

# %%
def main():
    
    dependencies, steps_that_follow = create_dependencies_dictionaries('input.txt')
    available_steps = find_possible_starts2(dependencies)
    
    steps_in_order = ""
    
    while dependencies.keys():
        
        step_taken, steps_in_order = take_step2(available_steps, steps_in_order, dependencies)
        print("Step taken: ", step_taken)
        print("Steps in Order", steps_in_order)

        add_available_steps2(step_taken, available_steps, dependencies, steps_that_follow)

# %% [markdown]
# ## Test

# %%
### Display initial dictionaries with dependencies and steps that follow

dependencies, steps_that_follow = create_dependencies_dictionaries('input.txt')

#display dictionary with dependencies
print("Dictionary of Dependencies: ")
for key, value in sorted(dependencies.items()):
    print(key, ": ", value)

#display steps that follow
print("Steps that Follow: ")
for key, value in sorted(steps_that_follow.items()):
    print(key, ": ", value)
# Out:
# Dictionary of Dependencies:
# A :  {'J', 'K', 'U', 'Y', 'W', 'L'}
# C :  {'H', 'J', 'P', 'L', 'Y', 'I', 'W', 'A'}
# D :  {'H', 'J', 'P', 'C', 'O', 'Q', 'N', 'A'}
# E :  {'S', 'J', 'D', 'C', 'G', 'I', 'O', 'Q', 'A'}
# H :  {'I', 'X', 'N'}
# I :  {'F', 'T', 'X'}
# J :  {'Y', 'U', 'M', 'Z'}
# K :  {'B'}
# L :  {'M', 'G', 'P', 'K'}
# M :  {'R', 'U', 'K'}
# N :  {'F'}
# O :  {'V', 'K', 'Z', 'U', 'P', 'Q', 'N', 'L'}
# P :  {'I', 'H', 'G'}
# Q :  {'U', 'T', 'W', 'H'}
# R :  {'B'}
# S :  {'Z', 'D', 'X', 'C', 'Y', 'O', 'Q', 'N', 'L'}
# T :  {'B'}
# U :  {'F', 'T', 'I'}
# V :  {'H', 'P', 'T', 'W', 'L'}
# W :  {'T', 'R'}
# X :  {'R'}
# Y :  {'R', 'V', 'X', 'P', 'I', 'Q', 'O', 'N', 'B', 'W'}
# Z :  {'T', 'R', 'B', 'G'}
# Steps that Follow:
# A :  {'C', 'D', 'E'}
# B :  {'R', 'K', 'Z', 'Y', 'T'}
# C :  {'D', 'S', 'E'}
# D :  {'S', 'E'}
# F :  {'I', 'U', 'N'}
# G :  {'E', 'P', 'L', 'Z'}
# H :  {'V', 'D', 'P', 'C', 'Q'}
# I :  {'H', 'E', 'U', 'P', 'Y', 'C'}
# J :  {'D', 'C', 'A', 'E'}
# K :  {'M', 'O', 'A', 'L'}
# L :  {'V', 'S', 'C', 'O', 'A'}
# M :  {'J', 'L'}
# N :  {'S', 'H', 'D', 'Y', 'O'}
# O :  {'D', 'S', 'Y', 'E'}
# P :  {'V', 'D', 'Y', 'C', 'O', 'L'}
# Q :  {'S', 'E', 'D', 'Y', 'O'}
# R :  {'Z', 'X', 'Y', 'M', 'W'}
# S :  {'E'}
# T :  {'V', 'Z', 'U', 'I', 'Q', 'W'}
# U :  {'J', 'M', 'Q', 'O', 'A'}
# V :  {'Y', 'O'}
# W :  {'V', 'C', 'Y', 'Q', 'A'}
# X :  {'Y', 'I', 'S', 'H'}
# Y :  {'C', 'S', 'J', 'A'}
# Z :  {'O', 'S', 'J'}

# %% [markdown]
# <div class="alert alert-success">
# <h3>Execute the Program and Solve the Problem!</h3>
# </div>

# %%
main()
# Out:
# Step taken:  B
# Steps in Order B
# Step taken:  F
# Steps in Order BF
# Step taken:  G
# Steps in Order BFG
# Step taken:  K
# Steps in Order BFGK
# Step taken:  N
# Steps in Order BFGKN
# Step taken:  R
# Steps in Order BFGKNR
# Step taken:  T
# Steps in Order BFGKNRT
# Step taken:  W
# Steps in Order BFGKNRTW
# Step taken:  X
# Steps in Order BFGKNRTWX
# Step taken:  I
# Steps in Order BFGKNRTWXI
# Step taken:  H
# Steps in Order BFGKNRTWXIH
# Step taken:  P
# Steps in Order BFGKNRTWXIHP
# Step taken:  U
# Steps in Order BFGKNRTWXIHPU
# Step taken:  M
# Steps in Order BFGKNRTWXIHPUM
# Step taken:  L
# Steps in Order BFGKNRTWXIHPUML
# Step taken:  Q
# Steps in Order BFGKNRTWXIHPUMLQ
# Step taken:  V
# Steps in Order BFGKNRTWXIHPUMLQV
# Step taken:  Z
# Steps in Order BFGKNRTWXIHPUMLQVZ
# Step taken:  O
# Steps in Order BFGKNRTWXIHPUMLQVZO
# Step taken:  Y
# Steps in Order BFGKNRTWXIHPUMLQVZOY
# Step taken:  J
# Steps in Order BFGKNRTWXIHPUMLQVZOYJ
# Step taken:  A
# Steps in Order BFGKNRTWXIHPUMLQVZOYJA
# Step taken:  C
# Steps in Order BFGKNRTWXIHPUMLQVZOYJAC
# Step taken:  D
# Steps in Order BFGKNRTWXIHPUMLQVZOYJACD
# Step taken:  S
# Steps in Order BFGKNRTWXIHPUMLQVZOYJACDS
# Step taken:  E
# Steps in Order BFGKNRTWXIHPUMLQVZOYJACDSE

# %% [markdown]
# ## --- Part Two ---

# %% [markdown]
# As you're about to begin construction, four of the Elves offer to help. "The sun will set soon; it'll go faster if we work together." Now, you need to account for multiple people working on steps simultaneously. If multiple steps are available, workers should still begin them in alphabetical order.
#
# Each step takes 60 seconds plus an amount corresponding to its letter: A=1, B=2, C=3, and so on. So, step A takes 60+1=61 seconds, while step Z takes 60+26=86 seconds. No time is required between steps.
#
# To simplify things for the example, however, suppose you only have help from one Elf (a total of two workers) and that each step takes 60 fewer seconds (so that step A takes 1 second and step Z takes 26 seconds). Then, using the same instructions as above, this is how each second would be spent:
#
#     Second   Worker 1   Worker 2   Done
#        0        C          .
#        1        C          .
#        2        C          .
#        3        A          F       C
#        4        B          F       CA
#        5        B          F       CA
#        6        D          F       CAB
#        7        D          F       CAB
#        8        D          F       CAB
#        9        D          .       CABF
#       10        E          .       CABFD
#       11        E          .       CABFD
#       12        E          .       CABFD
#       13        E          .       CABFD
#       14        E          .       CABFD
#       15        .          .       CABFDE
#
#
# Each row represents one second of time. The Second column identifies how many seconds have passed as of the beginning of that second. Each worker column shows the step that worker is currently doing (or . if they are idle). The Done column shows completed steps.
#
# Note that the order of the steps has changed; this is because steps now take time to finish and multiple workers can begin multiple steps simultaneously.
#
# In this example, it would take 15 seconds for two workers to complete these steps.
#
# **With 5 workers and the 60+ second step durations described above, how long will it take to complete all of the steps?**

# %% [markdown]
# ## Design
#
#
# ### Subtask one:
# create a dictionary with key=step, value=its ducration
#
# Design:
# - create a list containing all steps, which are all uppercase letters of the English alphabet
# - use enumerate function starting from 60 to create durations for each step
# - create a dictionary with key=step, value=duration
#
# ### Subtask Two
#
# Keep track of the following:
# - if worker is free or busy
# - which tasks become available
# - if all workers are busy, the next task should be allocated to a worker that will be free the soonest
#
#
# **Data structures**
#
# Dictionary for alphabet and ducration dicts: for ease of look-up
#
# Set of available steps (same reasoning as in part one)
#
# Lists for
# 1. is worker busy
# 2. how much time does every worker need to complete theor task
# 3. which task they are working on
#
# Why lists?
# Position in lists reflect the index of worker.
#
#         is_worker_busy = [False, False, False, False, False]
#         time_elapsed_for_worker = [0, 0, 0, 0, 0]
#         working_on_task = ['', '', '', '', '']

# %%
def create_alphabet_dict():
    '''Creates two dictionaries:
    - Letter: its duration 
    and
    - Duration : its letter'''
    
    alphabet_list = [chr(i) for i in range(ord('A'),ord('Z')+1)]
    alphabet_seconds = list(enumerate(alphabet_list, 61))
    alphabet_dict = {letter:seconds for (seconds,letter) in alphabet_seconds}
    duration_dict = {str(seconds):letter for (seconds,letter) in alphabet_seconds}
    
    return alphabet_dict, duration_dict

# %%
def take_step2(available_steps, dependencies):
    
    
    step_to_take = sorted(available_steps)[0]
    available_steps.remove(step_to_take)
    if step_to_take in dependencies:
        del dependencies[step_to_take]
    
        
    return step_to_take

# %%
def add_available_steps2(step_taken, available_steps, dependencies, steps_that_follow):
    for step in steps_that_follow[step_taken]:
        if step in dependencies and step_taken in dependencies[step]:
            dependencies[step].remove(step_taken)
            if dependencies[step] == set():
                available_steps.add(step)
        
    return available_steps

# %%
def main_task_two_first_draft():    
    
    #Subtask One
    alphabet_dict, duration_dict = create_alphabet_dict()
    dependencies, steps_that_follow = create_dependencies_dictionaries('input.txt')
    available_steps = find_possible_starts2(dependencies)
    
    #Subtask two
    time_elapsed = 0
    is_worker_busy = [False, False, False, False, False]
    time_elapsed_for_worker = [0, 0, 0, 0, 0]
    working_on_task = ['', '', '', '', '']

    for i in range(40):
        if not available_steps:
            time_elapsed_for_worker_no_zeros = [num for num in time_elapsed_for_worker if num != 0]
            step_quickest_to_finish = duration_dict[str(min(time_elapsed_for_worker_no_zeros))]
            add_available_steps2(step_quickest_to_finish, available_steps, dependencies, steps_that_follow)
            working_on_task[working_on_task.index(step_quickest_to_finish)] = ""
                
                
                
        elif available_steps:
            #find lowest time elapsed
            next_available_time_slot = min(time_elapsed_for_worker)
            #find index of worker with least time elapsed
            next_available_worker_index = time_elapsed_for_worker.index(next_available_time_slot)
            is_worker_busy[next_available_worker_index] = True
            step_taken = sorted(available_steps)[0]
            working_on_task[next_available_worker_index] = step_taken
            time_elapsed_for_worker[next_available_worker_index] += alphabet_dict[step_taken]
            time_elapsed += alphabet_dict[step_taken]
            step_taken = take_step2(available_steps, dependencies)

            print('Time Elapsed:', time_elapsed)
            print('is_worker_busy:', is_worker_busy)
            print('time_elapsed_for_worker', time_elapsed_for_worker)
            print('working_on_task', working_on_task)
            print("Step taken: ", step_taken)
            print('available_steps', available_steps)


            print("Dictionary of Dependencies: ")
            for key, value in sorted(dependencies.items()):
                print(key, ": ", value)
    
#     print("Steps in Order", steps_in_order)

# %%
main_task_two_first_draft()
# Out:
# 62
# [True, False, False, False, False]
# [62, 0, 0, 0, 0]
# ['B', '', '', '', '']
# Step taken:  B
# {'G', 'F'}
# Dictionary of Dependencies:
# A :  {'W', 'L', 'U', 'Y', 'J', 'K'}
# C :  {'W', 'A', 'L', 'Y', 'H', 'P', 'J', 'I'}
# D :  {'A', 'C', 'Q', 'H', 'P', 'O', 'J', 'N'}
# E :  {'A', 'C', 'G', 'D', 'O', 'Q', 'S', 'J', 'I'}
# H :  {'I', 'N', 'X'}
# I :  {'T', 'F', 'X'}
# J :  {'M', 'Z', 'U', 'Y'}
# K :  {'B'}
# L :  {'M', 'G', 'K', 'P'}
# M :  {'R', 'K', 'U'}
# N :  {'F'}
# O :  {'V', 'L', 'N', 'U', 'Q', 'Z', 'P', 'K'}
# P :  {'I', 'H', 'G'}
# Q :  {'W', 'T', 'H', 'U'}
# R :  {'B'}
# S :  {'L', 'C', 'X', 'Y', 'D', 'Q', 'Z', 'O', 'N'}
# T :  {'B'}
# U :  {'T', 'I', 'F'}
# V :  {'W', 'L', 'T', 'H', 'P'}
# W :  {'T', 'R'}
# X :  {'R'}
# Y :  {'V', 'W', 'X', 'Q', 'B', 'P', 'O', 'I', 'R', 'N'}
# Z :  {'T', 'G', 'R', 'B'}
# 128
# [True, True, False, False, False]
# [62, 66, 0, 0, 0]
# ['B', 'F', '', '', '']
# Step taken:  F
# {'G'}
# Dictionary of Dependencies:
# A :  {'W', 'L', 'U', 'Y', 'J', 'K'}
# C :  {'W', 'A', 'L', 'Y', 'H', 'P', 'J', 'I'}
# D :  {'A', 'C', 'Q', 'H', 'P', 'O', 'J', 'N'}
# E :  {'A', 'C', 'G', 'D', 'O', 'Q', 'S', 'J', 'I'}
# H :  {'I', 'N', 'X'}
# I :  {'T', 'F', 'X'}
# J :  {'M', 'Z', 'U', 'Y'}
# K :  {'B'}
# L :  {'M', 'G', 'K', 'P'}
# M :  {'R', 'K', 'U'}
# N :  {'F'}
# O :  {'V', 'L', 'N', 'U', 'Q', 'Z', 'P', 'K'}
# P :  {'I', 'H', 'G'}
# Q :  {'W', 'T', 'H', 'U'}
# R :  {'B'}
# S :  {'L', 'C', 'X', 'Y', 'D', 'Q', 'Z', 'O', 'N'}
# T :  {'B'}
# U :  {'T', 'I', 'F'}
# V :  {'W', 'L', 'T', 'H', 'P'}
# W :  {'T', 'R'}
# X :  {'R'}
# Y :  {'V', 'W', 'X', 'Q', 'B', 'P', 'O', 'I', 'R', 'N'}
# Z :  {'T', 'G', 'R', 'B'}
# 195
# [True, True, True, False, False]
# [62, 66, 67, 0, 0]
# ['B', 'F', 'G', '', '']
# Step taken:  G
# set()
# Dictionary of Dependencies:
# A :  {'W', 'L', 'U', 'Y', 'J', 'K'}
# C :  {'W', 'A', 'L', 'Y', 'H', 'P', 'J', 'I'}
# D :  {'A', 'C', 'Q', 'H', 'P', 'O', 'J', 'N'}
# E :  {'A', 'C', 'G', 'D', 'O', 'Q', 'S', 'J', 'I'}
# H :  {'I', 'N', 'X'}
# I :  {'T', 'F', 'X'}
# J :  {'M', 'Z', 'U', 'Y'}
# K :  {'B'}
# L :  {'M', 'G', 'K', 'P'}
# M :  {'R', 'K', 'U'}
# N :  {'F'}
# O :  {'V', 'L', 'N', 'U', 'Q', 'Z', 'P', 'K'}
# P :  {'I', 'H', 'G'}
# Q :  {'W', 'T', 'H', 'U'}
# R :  {'B'}
# S :  {'L', 'C', 'X', 'Y', 'D', 'Q', 'Z', 'O', 'N'}
# T :  {'B'}
# U :  {'T', 'I', 'F'}
# V :  {'W', 'L', 'T', 'H', 'P'}
# W :  {'T', 'R'}
# X :  {'R'}
# Y :  {'V', 'W', 'X', 'Q', 'B', 'P', 'O', 'I', 'R', 'N'}
# Z :  {'T', 'G', 'R', 'B'}
# 266
# [True, True, True, True, False]
# [62, 66, 67, 71, 0]
# ['', 'F', 'G', 'K', '']
# Step taken:  K
# {'T', 'R'}
# Dictionary of Dependencies:
# A :  {'W', 'L', 'U', 'Y', 'J', 'K'}
# C :  {'W', 'A', 'L', 'Y', 'H', 'P', 'J', 'I'}
# D :  {'A', 'C', 'Q', 'H', 'P', 'O', 'J', 'N'}
# E :  {'A', 'C', 'G', 'D', 'O', 'Q', 'S', 'J', 'I'}
# H :  {'I', 'N', 'X'}
# I :  {'T', 'F', 'X'}
# J :  {'M', 'Z', 'U', 'Y'}
# L :  {'M', 'G', 'K', 'P'}
# M :  {'R', 'K', 'U'}
# N :  {'F'}
# O :  {'V', 'L', 'N', 'U', 'Q', 'Z', 'P', 'K'}
# P :  {'I', 'H', 'G'}
# Q :  {'W', 'T', 'H', 'U'}
# R :  set()
# S :  {'L', 'C', 'X', 'Y', 'D', 'Q', 'Z', 'O', 'N'}
# T :  set()
# U :  {'T', 'I', 'F'}
# V :  {'W', 'L', 'T', 'H', 'P'}
# W :  {'T', 'R'}
# X :  {'R'}
# Y :  {'V', 'W', 'X', 'Q', 'P', 'O', 'I', 'R', 'N'}
# Z :  {'T', 'G', 'R'}
# 344
# [True, True, True, True, True]
# [62, 66, 67, 71, 78]
# ['', 'F', 'G', 'K', 'R']
# Step taken:  R
# {'T'}
# Dictionary of Dependencies:
# A :  {'W', 'L', 'U', 'Y', 'J', 'K'}
# C :  {'W', 'A', 'L', 'Y', 'H', 'P', 'J', 'I'}
# D :  {'A', 'C', 'Q', 'H', 'P', 'O', 'J', 'N'}
# E :  {'A', 'C', 'G', 'D', 'O', 'Q', 'S', 'J', 'I'}
# H :  {'I', 'N', 'X'}
# I :  {'T', 'F', 'X'}
# J :  {'M', 'Z', 'U', 'Y'}
# L :  {'M', 'G', 'K', 'P'}
# M :  {'R', 'K', 'U'}
# N :  {'F'}
# O :  {'V', 'L', 'N', 'U', 'Q', 'Z', 'P', 'K'}
# P :  {'I', 'H', 'G'}
# Q :  {'W', 'T', 'H', 'U'}
# S :  {'L', 'C', 'X', 'Y', 'D', 'Q', 'Z', 'O', 'N'}
# T :  set()
# U :  {'T', 'I', 'F'}
# V :  {'W', 'L', 'T', 'H', 'P'}
# W :  {'T', 'R'}
# X :  {'R'}
# Y :  {'V', 'W', 'X', 'Q', 'P', 'O', 'I', 'R', 'N'}
# Z :  {'T', 'G', 'R'}
# 424
# [True, True, True, True, True]
# [142, 66, 67, 71, 78]
# ['T', 'F', 'G', 'K', 'R']
# Step taken:  T
# set()
# Dictionary of Dependencies:
# A :  {'W', 'L', 'U', 'Y', 'J', 'K'}
# C :  {'W', 'A', 'L', 'Y', 'H', 'P', 'J', 'I'}
# D :  {'A', 'C', 'Q', 'H', 'P', 'O', 'J', 'N'}
# E :  {'A', 'C', 'G', 'D', 'O', 'Q', 'S', 'J', 'I'}
# H :  {'I', 'N', 'X'}
# I :  {'T', 'F', 'X'}
# J :  {'M', 'Z', 'U', 'Y'}
# L :  {'M', 'G', 'K', 'P'}
# M :  {'R', 'K', 'U'}
# N :  {'F'}
# O :  {'V', 'L', 'N', 'U', 'Q', 'Z', 'P', 'K'}
# P :  {'I', 'H', 'G'}
# Q :  {'W', 'T', 'H', 'U'}
# S :  {'L', 'C', 'X', 'Y', 'D', 'Q', 'Z', 'O', 'N'}
# U :  {'T', 'I', 'F'}
# V :  {'W', 'L', 'T', 'H', 'P'}
# W :  {'T', 'R'}
# X :  {'R'}
# Y :  {'V', 'W', 'X', 'Q', 'P', 'O', 'I', 'R', 'N'}
# Z :  {'T', 'G', 'R'}
# 498
# [True, True, True, True, True]
# [142, 140, 67, 71, 78]
# ['T', 'N', 'G', 'K', 'R']
# Step taken:  N
# set()
# Dictionary of Dependencies:
# A :  {'W', 'L', 'U', 'Y', 'J', 'K'}
# C :  {'W', 'A', 'L', 'Y', 'H', 'P', 'J', 'I'}
# D :  {'A', 'C', 'Q', 'H', 'P', 'O', 'J', 'N'}
# E :  {'A', 'C', 'G', 'D', 'O', 'Q', 'S', 'J', 'I'}
# H :  {'I', 'N', 'X'}
# I :  {'T', 'X'}
# J :  {'M', 'Z', 'U', 'Y'}
# L :  {'M', 'G', 'K', 'P'}
# M :  {'R', 'K', 'U'}
# O :  {'V', 'L', 'N', 'U', 'Q', 'Z', 'P', 'K'}
# P :  {'I', 'H', 'G'}
# Q :  {'W', 'T', 'H', 'U'}
# S :  {'L', 'C', 'X', 'Y', 'D', 'Q', 'Z', 'O', 'N'}
# U :  {'T', 'I'}
# V :  {'W', 'L', 'T', 'H', 'P'}
# W :  {'T', 'R'}
# X :  {'R'}
# Y :  {'V', 'W', 'X', 'Q', 'P', 'O', 'I', 'R', 'N'}
# Z :  {'T', 'G', 'R'}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-117-0c323df7e0ec> in <module>
# ----> 1 main_task_two_first_draft()
#
# <ipython-input-116-ea96fc0704b9> in main_task_two_first_draft()
#      28             step_quickest_to_finish = duration_dict[str(min(time_elapsed_for_worker_no_zeros))]
#      29             add_available_steps2(step_quickest_to_finish, available_steps, dependencies, steps_that_follow)
# ---> 30             working_on_task[working_on_task.index(step_quickest_to_finish)] = ""
#      31
#      32
#
# ValueError: 'G' is not in list

# %% [markdown]
# ## Debug

# %% [markdown]
# <div class="alert alert-warning">
# <h3>Debug</h3>
#
# 1. Reproduce
# 2. Diagnose
# 3. Fix
# 4. Reflect
#
# </div>

# %% [markdown]
# ##### 1. Reproduce
#
# The Error Message is the following
#
#     ValueError: 'G' is not in list.
#
# The problem occures in the line
#
#        working_on_task[working_on_task.index(step_quickest_to_finish)] = ""
#
# ##### 2. Diagnose
# A step is not in the working_on_task list.
# This happends because we try to remove a step from the list of tasks that workers are currently working on after adding the steps made available after acomplishing this task.
# E.g.: 'G' is the quickest to acomplish. Remove 'G' as dependency from all steps that rquire it. Add steps that now don't have any dependencies to available_steps list.
#
# The issue is: G is just removed, no new steps are added.
#
# ##### 3. Fix
# We need to simulate a timeline.
# First assign all available steps to all available workers.
#
# If more workers than steps available: the remaining workers can only start their tasks after the task with quickest duration is finished and maybe some new steps are made available through this.
#
# When all workers busy:
# the worker that will be do the soonest finishes, and new tasks may be made available. If now: next worker finishes, check if now tasks are available. Continue until find available tasks.
#
# **Data Structures**
#
#
# 1. list of workers. Element of list set to True if the worker has a task, False if free
# 2.2.
#
# Why list?
# Position of a list simulates the number of a worker: 0 for 1st worker, 4 for 5th worker.
#
# 2. Priority Queue with available steps
#
# Data structure: Sorted list. Initially available_steps is a set for ease of adding new elements and removing them.
#
#     sorted(available_steps)[0]
#
# 3. Priority queue with seconds elapsed for each worker. Once every worker started a task, tasks will be allocate to workers that finish their steps the quickest.
#
#          sorted(priority_queue_time)[0]
#
# ##### 4. Reflect
# Simulating a timeline was a challange. I had to make sure to separate the tasks that have been started and the tasks that are finished.
#
# Thinking about this task in form of a priority queue enabled me to simulate a timeline.

# %%
def take_step(available_steps, is_worker_busy, alphabet_dict, dependencies, priority_queue_time):
    
    '''
    Start taking step. Assign it to a worker. Remove it from available steps and
    dependencies dictionary.

    '''
    
    #for the beginning
    step_to_take = sorted(available_steps)[0]
    duration_of_step = alphabet_dict[step_to_take]
    free_worker = is_worker_busy.index(False)

    #remove step from available 
    available_steps.remove(step_to_take)

    #set worker to busy (True)
    is_worker_busy[free_worker] = True

    #delete from dependencies
    if step_to_take in dependencies:
        del dependencies[step_to_take]
        
    return duration_of_step, step_to_take, free_worker

# %%
def add_available_steps(finished_step, available_steps, dependencies, steps_that_follow):
    
    '''Add steps made available after a step has been finished'''
    
    if finished_step in steps_that_follow:
        for step in steps_that_follow[finished_step]:
            if finished_step in dependencies[step]:
                dependencies[step].remove(finished_step)
                if dependencies[step] == set():
                    del dependencies[step]
                    available_steps.add(step)
        return available_steps
    
    else:
        return False

# %%
def main():
    
    alphabet_dict, duration_dict = create_alphabet_dict()
    dependencies, steps_that_follow = create_dependencies_dictionaries('input.txt')
    available_steps = find_possible_starts2(dependencies)
    
    steps_in_order = []
    time_elapsed = 0
    is_worker_busy = [False, False, False, False, False]


    priority_queue_time = []
    print(priority_queue_time)
    
    while dependencies.keys() or available_steps:
        print(sorted(steps_in_order))
        if available_steps and False in is_worker_busy:
            print('available steps', available_steps)
            step_to_append = take_step(available_steps, is_worker_busy,
                                       alphabet_dict, dependencies, priority_queue_time)
            print("Step to append: ", step_to_append)
            
            search = step_to_append[2]
            if any(step_in_queue[2] == search for step_in_queue in priority_queue_time):
                step_to_replace = list(filter(lambda x:x[2]==search, priority_queue_time))
                print('step to replace', step_to_replace)
                updated_time = step_to_replace[0][0] + step_to_append[0]
                step_to_append = (updated_time, step_to_append[1], step_to_append[2])
                priority_queue_time.remove(step_to_replace[0])
                priority_queue_time.append(step_to_append)

            else:
                updated_time = time_elapsed + step_to_append[0]
                step_to_append = (updated_time, step_to_append[1], step_to_append[2])
                priority_queue_time.append(step_to_append)
                     
            print("priority queue with appended step:", priority_queue_time)
            
            print('after taking step is worker busy', is_worker_busy)
            
            

            
        elif not available_steps and dependencies.keys():
    
            #add newly available steps 
            counter = 0
            while not available_steps and counter <= len(priority_queue_time):
                print('counter for available steps:', counter)
                quickest_finished_step = sorted(priority_queue_time)[0]
                time_elapsed = sorted(priority_queue_time)[0][0]

                #set worker to free for the task that will be done the soonest
                is_worker_busy[sorted(priority_queue_time)[0][2]] = False

                available_steps = add_available_steps(quickest_finished_step[1], available_steps, 
                                                  dependencies, steps_that_follow)
                print("added steps from", quickest_finished_step[1], "these are ", 
                      available_steps)
                priority_queue_time.remove(quickest_finished_step)
                print('removed {} from queue. New queue is {}'.format(quickest_finished_step[1],
                                                                     priority_queue_time))
                print(time_elapsed)
                counter += 1
                
    if priority_queue_time:
        time_elapsed = sorted(priority_queue_time)[0][0]
            
    print('Answer:', time_elapsed)

# %% [markdown]
# <div class="alert alert-success">
# <h3>Execute the Program and Solve the Problem!</h3>
# </div>

# %%
### Display initial dictionaries with dependencies and steps that follow

dependencies, steps_that_follow = create_dependencies_dictionaries('input.txt')

#display dictionary with dependencies
print("Dictionary of Dependencies: ")
for key, value in sorted(dependencies.items()):
    print(key, ": ", value)

#display steps that follow
print("Steps that Follow: ")
for key, value in sorted(steps_that_follow.items()):
    print(key, ": ", value)
    
create_alphabet_dict()
# Out:
# Dictionary of Dependencies:
# A :  {'J', 'K', 'U', 'Y', 'W', 'L'}
# C :  {'H', 'J', 'P', 'L', 'Y', 'I', 'W', 'A'}
# D :  {'H', 'J', 'P', 'C', 'O', 'Q', 'N', 'A'}
# E :  {'S', 'J', 'D', 'C', 'G', 'I', 'O', 'Q', 'A'}
# H :  {'I', 'X', 'N'}
# I :  {'F', 'T', 'X'}
# J :  {'Y', 'U', 'M', 'Z'}
# K :  {'B'}
# L :  {'M', 'G', 'P', 'K'}
# M :  {'R', 'U', 'K'}
# N :  {'F'}
# O :  {'V', 'K', 'Z', 'U', 'P', 'Q', 'N', 'L'}
# P :  {'I', 'H', 'G'}
# Q :  {'U', 'T', 'W', 'H'}
# R :  {'B'}
# S :  {'Z', 'D', 'X', 'C', 'Y', 'O', 'Q', 'N', 'L'}
# T :  {'B'}
# U :  {'F', 'T', 'I'}
# V :  {'H', 'P', 'T', 'W', 'L'}
# W :  {'T', 'R'}
# X :  {'R'}
# Y :  {'R', 'V', 'X', 'P', 'I', 'Q', 'O', 'N', 'B', 'W'}
# Z :  {'T', 'R', 'B', 'G'}
# Steps that Follow:
# A :  {'C', 'D', 'E'}
# B :  {'R', 'K', 'Z', 'Y', 'T'}
# C :  {'D', 'S', 'E'}
# D :  {'S', 'E'}
# F :  {'I', 'U', 'N'}
# G :  {'E', 'P', 'L', 'Z'}
# H :  {'V', 'D', 'P', 'C', 'Q'}
# I :  {'H', 'E', 'U', 'P', 'Y', 'C'}
# J :  {'D', 'C', 'A', 'E'}
# K :  {'M', 'O', 'A', 'L'}
# L :  {'V', 'S', 'C', 'O', 'A'}
# M :  {'J', 'L'}
# N :  {'S', 'H', 'D', 'Y', 'O'}
# O :  {'D', 'S', 'Y', 'E'}
# P :  {'V', 'D', 'Y', 'C', 'O', 'L'}
# Q :  {'S', 'E', 'D', 'Y', 'O'}
# R :  {'Z', 'X', 'Y', 'M', 'W'}
# S :  {'E'}
# T :  {'V', 'Z', 'U', 'I', 'Q', 'W'}
# U :  {'J', 'M', 'Q', 'O', 'A'}
# V :  {'Y', 'O'}
# W :  {'V', 'C', 'Y', 'Q', 'A'}
# X :  {'Y', 'I', 'S', 'H'}
# Y :  {'C', 'S', 'J', 'A'}
# Z :  {'O', 'S', 'J'}
# ({'A': 61,
#   'B': 62,
#   'C': 63,
#   'D': 64,
#   'E': 65,
#   'F': 66,
#   'G': 67,
#   'H': 68,
#   'I': 69,
#   'J': 70,
#   'K': 71,
#   'L': 72,
#   'M': 73,
#   'N': 74,
#   'O': 75,
#   'P': 76,
#   'Q': 77,
#   'R': 78,
#   'S': 79,
#   'T': 80,
#   'U': 81,
#   'V': 82,
#   'W': 83,
#   'X': 84,
#   'Y': 85,
#   'Z': 86},
#  {'61': 'A',
#   '62': 'B',
#   '63': 'C',
#   '64': 'D',
#   '65': 'E',
#   '66': 'F',
#   '67': 'G',
#   '68': 'H',
#   '69': 'I',
#   '70': 'J',
#   '71': 'K',
#   '72': 'L',
#   '73': 'M',
#   '74': 'N',
#   '75': 'O',
#   '76': 'P',
#   '77': 'Q',
#   '78': 'R',
#   '79': 'S',
#   '80': 'T',
#   '81': 'U',
#   '82': 'V',
#   '83': 'W',
#   '84': 'X',
#   '85': 'Y',
#   '86': 'Z'})

# %%
main()
# Out:
# []
# []
# available steps {'F', 'G', 'B'}
# Step to append:  (62, 'B', 0)
# priority queue with appended step: [(62, 'B', 0)]
# after taking step is worker busy [True, False, False, False, False]
# []
# available steps {'F', 'G'}
# Step to append:  (66, 'F', 1)
# priority queue with appended step: [(62, 'B', 0), (66, 'F', 1)]
# after taking step is worker busy [True, True, False, False, False]
# []
# available steps {'G'}
# Step to append:  (67, 'G', 2)
# priority queue with appended step: [(62, 'B', 0), (66, 'F', 1), (67, 'G', 2)]
# after taking step is worker busy [True, True, True, False, False]
# []
# counter for available steps: 0
# added steps from B these are  {'T', 'R', 'K'}
# removed B from queue. New queue is [(66, 'F', 1), (67, 'G', 2)]
# 62
# []
# available steps {'T', 'R', 'K'}
# Step to append:  (71, 'K', 0)
# priority queue with appended step: [(66, 'F', 1), (67, 'G', 2), (133, 'K', 0)]
# after taking step is worker busy [True, True, True, False, False]
# []
# available steps {'T', 'R'}
# Step to append:  (78, 'R', 3)
# priority queue with appended step: [(66, 'F', 1), (67, 'G', 2), (133, 'K', 0), (140, 'R', 3)]
# after taking step is worker busy [True, True, True, True, False]
# []
# available steps {'T'}
# Step to append:  (80, 'T', 4)
# priority queue with appended step: [(66, 'F', 1), (67, 'G', 2), (133, 'K', 0), (140, 'R', 3), (142, 'T', 4)]
# after taking step is worker busy [True, True, True, True, True]
# []
# counter for available steps: 0
# added steps from F these are  {'N'}
# removed F from queue. New queue is [(67, 'G', 2), (133, 'K', 0), (140, 'R', 3), (142, 'T', 4)]
# 66
# []
# available steps {'N'}
# Step to append:  (74, 'N', 1)
# priority queue with appended step: [(67, 'G', 2), (133, 'K', 0), (140, 'R', 3), (142, 'T', 4), (140, 'N', 1)]
# after taking step is worker busy [True, True, True, True, True]
# []
# counter for available steps: 0
# added steps from G these are  set()
# removed G from queue. New queue is [(133, 'K', 0), (140, 'R', 3), (142, 'T', 4), (140, 'N', 1)]
# 67
# counter for available steps: 1
# added steps from K these are  set()
# removed K from queue. New queue is [(140, 'R', 3), (142, 'T', 4), (140, 'N', 1)]
# 133
# counter for available steps: 2
# added steps from N these are  set()
# removed N from queue. New queue is [(140, 'R', 3), (142, 'T', 4)]
# 140
# []
# counter for available steps: 0
# added steps from R these are  {'X'}
# removed R from queue. New queue is [(142, 'T', 4)]
# 140
# []
# available steps {'X'}
# Step to append:  (84, 'X', 0)
# priority queue with appended step: [(142, 'T', 4), (224, 'X', 0)]
# after taking step is worker busy [True, False, False, False, True]
# []
# counter for available steps: 0
# added steps from T these are  {'W', 'Z'}
# removed T from queue. New queue is [(224, 'X', 0)]
# 142
# []
# available steps {'W', 'Z'}
# Step to append:  (83, 'W', 1)
# priority queue with appended step: [(224, 'X', 0), (225, 'W', 1)]
# after taking step is worker busy [True, True, False, False, False]
# []
# available steps {'Z'}
# Step to append:  (86, 'Z', 2)
# priority queue with appended step: [(224, 'X', 0), (225, 'W', 1), (228, 'Z', 2)]
# after taking step is worker busy [True, True, True, False, False]
# []
# counter for available steps: 0
# added steps from X these are  {'I'}
# removed X from queue. New queue is [(225, 'W', 1), (228, 'Z', 2)]
# 224
# []
# available steps {'I'}
# Step to append:  (69, 'I', 0)
# priority queue with appended step: [(225, 'W', 1), (228, 'Z', 2), (293, 'I', 0)]
# after taking step is worker busy [True, True, True, False, False]
# []
# counter for available steps: 0
# added steps from W these are  set()
# removed W from queue. New queue is [(228, 'Z', 2), (293, 'I', 0)]
# 225
# counter for available steps: 1
# added steps from Z these are  set()
# removed Z from queue. New queue is [(293, 'I', 0)]
# 228
# []
# counter for available steps: 0
# added steps from I these are  {'H', 'U'}
# removed I from queue. New queue is []
# 293
# []
# available steps {'H', 'U'}
# Step to append:  (68, 'H', 0)
# priority queue with appended step: [(361, 'H', 0)]
# after taking step is worker busy [True, False, False, False, False]
# []
# available steps {'U'}
# Step to append:  (81, 'U', 1)
# priority queue with appended step: [(361, 'H', 0), (374, 'U', 1)]
# after taking step is worker busy [True, True, False, False, False]
# []
# counter for available steps: 0
# added steps from H these are  {'P'}
# removed H from queue. New queue is [(374, 'U', 1)]
# 361
# []
# available steps {'P'}
# Step to append:  (76, 'P', 0)
# priority queue with appended step: [(374, 'U', 1), (437, 'P', 0)]
# after taking step is worker busy [True, True, False, False, False]
# []
# counter for available steps: 0
# added steps from U these are  {'M', 'Q'}
# removed U from queue. New queue is [(437, 'P', 0)]
# 374
# []
# available steps {'M', 'Q'}
# Step to append:  (73, 'M', 1)
# priority queue with appended step: [(437, 'P', 0), (447, 'M', 1)]
# after taking step is worker busy [True, True, False, False, False]
# []
# available steps {'Q'}
# Step to append:  (77, 'Q', 2)
# priority queue with appended step: [(437, 'P', 0), (447, 'M', 1), (451, 'Q', 2)]
# after taking step is worker busy [True, True, True, False, False]
# []
# counter for available steps: 0
# added steps from P these are  set()
# removed P from queue. New queue is [(447, 'M', 1), (451, 'Q', 2)]
# 437
# counter for available steps: 1
# added steps from M these are  {'L'}
# removed M from queue. New queue is [(451, 'Q', 2)]
# 447
# []
# available steps {'L'}
# Step to append:  (72, 'L', 0)
# priority queue with appended step: [(451, 'Q', 2), (519, 'L', 0)]
# after taking step is worker busy [True, False, True, False, False]
# []
# counter for available steps: 0
# added steps from Q these are  set()
# removed Q from queue. New queue is [(519, 'L', 0)]
# 451
# counter for available steps: 1
# added steps from L these are  {'V'}
# removed L from queue. New queue is []
# 519
# []
# available steps {'V'}
# Step to append:  (82, 'V', 0)
# priority queue with appended step: [(601, 'V', 0)]
# after taking step is worker busy [True, False, False, False, False]
# []
# counter for available steps: 0
# added steps from V these are  {'O'}
# removed V from queue. New queue is []
# 601
# []
# available steps {'O'}
# Step to append:  (75, 'O', 0)
# priority queue with appended step: [(676, 'O', 0)]
# after taking step is worker busy [True, False, False, False, False]
# []
# counter for available steps: 0
# added steps from O these are  {'Y'}
# removed O from queue. New queue is []
# 676
# []
# available steps {'Y'}
# Step to append:  (85, 'Y', 0)
# priority queue with appended step: [(761, 'Y', 0)]
# after taking step is worker busy [True, False, False, False, False]
# []
# counter for available steps: 0
# added steps from Y these are  {'J'}
# removed Y from queue. New queue is []
# 761
# []
# available steps {'J'}
# Step to append:  (70, 'J', 0)
# priority queue with appended step: [(831, 'J', 0)]
# after taking step is worker busy [True, False, False, False, False]
# []
# counter for available steps: 0
# added steps from J these are  {'A'}
# removed J from queue. New queue is []
# 831
# []
# available steps {'A'}
# Step to append:  (61, 'A', 0)
# priority queue with appended step: [(892, 'A', 0)]
# after taking step is worker busy [True, False, False, False, False]
# []
# counter for available steps: 0
# added steps from A these are  {'C'}
# removed A from queue. New queue is []
# 892
# []
# available steps {'C'}
# Step to append:  (63, 'C', 0)
# priority queue with appended step: [(955, 'C', 0)]
# after taking step is worker busy [True, False, False, False, False]
# []
# counter for available steps: 0
# added steps from C these are  {'D'}
# removed C from queue. New queue is []
# 955
# []
# available steps {'D'}
# Step to append:  (64, 'D', 0)
# priority queue with appended step: [(1019, 'D', 0)]
# after taking step is worker busy [True, False, False, False, False]
# []
# counter for available steps: 0
# added steps from D these are  {'S'}
# removed D from queue. New queue is []
# 1019
# []
# available steps {'S'}
# Step to append:  (79, 'S', 0)
# priority queue with appended step: [(1098, 'S', 0)]
# after taking step is worker busy [True, False, False, False, False]
# []
# counter for available steps: 0
# added steps from S these are  {'E'}
# removed S from queue. New queue is []
# 1098
# []
# available steps {'E'}
# Step to append:  (65, 'E', 0)
# priority queue with appended step: [(1163, 'E', 0)]
# after taking step is worker busy [True, False, False, False, False]
# Answer: 1163

# %% [markdown]
# <div class="alert alert-info">
# <h3>Evaluate & Reflect (2 pts)</h3>
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#   <h5>Evaluate</h5>
#
#   Evaluate your solution (=code) according to the criteria:
#   <ol>
#     <li>Functionality</li>
#     <li>Design & Code</li>
#     <li>Readability, Style & Documentation</li>
#   </ol>
#
# Write at least one paragraph.
#
# </div>

# %% [markdown]
# **Functionality**
#
# The code solves both part one and part two of the tasks.
# Incremental design shows my progress from buggy non-functional to fully-functional code.
#
# **Design and Code**
#
# Having written a functioning first part, I have challenged myself to make it mode efficient, which I accomplished.
# The code was broken down into subtasks.
# The data structures were explained.
# The reusable and repeatable parts of the code have been packed into functions.
#
# **Readability, Style & Documentation**
#
# I tried to document and explain both the big picture, but also the practical implementation.
# I was more elaborate with this on the first task. The second part had a lot of similarities with the first, so I considered some parts to be already explained and therefore did not go that much into detail.
#
# In the beginning I sticked to a rather strict doc-string style, which I shifted away from later on, since I found copying the parameter and return type descriptions repetative and rather unnecessary.

# %% [markdown]
# <div class="alert alert-warning">
# <h5>Reflect</h5>
#
# Reflect on your work. Write at least one paragraph.
# </div>

# %% [markdown]
# This can very well be my favourite task from this semester. I really enjoyed applying the step-by-step approach, with documentation of bugs, their fixes and my reflection on it.
#
# Looking through the document, I see how my design has improved and the code became more elegant and understandable.
#
# It has been time consuming too. I wish I've had one more week to add more fine-grained detailes to the explanation of the design details. But I hope that I found a reasonably good balance between detail and not sinking into every change I made.

# %% [markdown]
# <hr style="height: 10px; background-color:black;">
# <hr style="height: 10px; background-color:black;">
#
# ## OKpy - Submitting the Mini-Project
#
# In this task OKpy is used only for submitting the mini-project. You will need to write your own testing.
#
# Once you're finished, select "Save and Checkpoint" in the File menu and then execute the submit cell below. The result will contain a link that you can use to check that your assignment has been submitted successfully. If you submit more than once before the deadline, we will only grade your final submission.

# %%
# Don't change this cell; just run it.

from client.api.notebook import Notebook
ok = Notebook('miniproject.ok')
_ = ok.auth(inline=False)

_ = ok.submit()
# Out:
# =====================================================================
# Assignment: Homework 11
# OK, version v1.13.11
# =====================================================================
# Saving notebook... Saved 'problem-solving-walkthrough.ipynb'.
# Submit... 100% complete
# Submission successful for user: olenavshn@gmail.com
# URL: https://okpy.org/up/py/wi18/miniproject/submissions/wV2W5r
